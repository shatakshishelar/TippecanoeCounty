# %%
import pandas as pd

def process_file(file_path):
    df = pd.read_csv(file_path)

    df_false = df[df['Reclassified'] == False]

    reason_counts = df_false['Explanation'].value_counts()

    print(f"Results for {file_path}:")
    print("Unique Reasons with Counts:")
    for reason, count in reason_counts.items():
        print(f"{reason}: {count}")
    print("\n")

process_file("tippecanoe/Combined_Reconciliation_2023_2.csv")
# Out:
# Results for tippecanoe/Combined_Reconciliation_2023_2.csv:
# Unique Reasons with Counts:
# LAND: 31
# Value per GRM per IC 6-1.1-4-39(b): 24
# Insufficant Sales: 15
# Invalid Sale-No Consideration: 11
# SIGNIFCANT CHANGES: 10
# EXCLUDED - UNDER $10,000: 10
# Relocation: 10
# no money amount: 10
# Maybe: 9
# Part Of Porfolio Sale: 9
# Commissioners Sale: 8
# SOLD TO TENANT: 6
# EXCLUDED - SALE PRICE INCLUDES 10 PARCELS: 6
# SALE INCLUDED NON-REAL PROPERTY, VALUE NOT DISCLOSED: 6
# 1/2 NON ADJ PARCEL TR: 5
# EXCLUDED - HAS SINCE SOLD: 5
# SIGNIFICATE CHANGES: 5
# EXCLUDED - SOLD FOR $10,000: 5
# AMMF IS TAKING TITLE TO PROPERTY AND WILL THEN TRANSFER TO NEW OWNER - NOT A SALE: 5
# Buyer not knowledgeable: 5
# V-V: 4
# EXCLUDED - 6 PARCLES IN 1 SALE PRICE: 4
# 2 DAYS ON MARKET: 4
# HIGHER END HOME: 4
# Res And Ci Sold Together: 4
# Problem Deed: 4
# ONLY 3 DAYS ON MARKET: 4
# 2/2 NON ADJ PARCEL TR: 4
# INSUFFICIANT SALES: 4
# ONE SALE PRICE FOR 4 NON0CONTIG PROPERTIES: 4
# INVALID; PENDED AT LISTING: 3
# delevoper sale: 3
# Valid Sale- ComImp: 3
# SIGNFICANT CHANGES: 3
# EXCLUDED - HOME OWNERS OWN PART OF THE LAKE HOWEVER LAKE IS NOT ASSESSABLE: 3
# Res Imp: 3
# EXCLUDED - SALE ON 3 SEPARATE DISCLOSURES: 3
# NO HOUSE: 3
# corp sale: 3
# Part of Corp Sale: 3
# Not Rep Of Nbhd: 2
# HABITAT FOR HUMANITY HOME: 2
# RELOCATION SERVICE: 2
# SECONDARY HOME: 2
# PROPERTY WILL NOT TRANSFER UNTIL 2023: 2
# CLOSED SLAE: 2
# 1/5 NON ADJ PARCEL TR: 2
# 1/3 NON ADJ PARCEL TR: 2
# Includes NC not yet completed: 2
# SIGNIFIANT CHANGES: 2
# 3/3 NON ADJ PARCEL TR: 2
# INVALID - NON-MRKT TRANSACTION - SOLD FOR $15,600 (11%) LESS** THAN AV: 2
# INVALID; PENDED AT LIST: 2
# sale of unbuildable lot in lake community: 2
# MUPLTIPLE SALES IN ONE YEAR: 2
# Same Buyer/Seller: 2
# ONLY 3 DAYS ON THE MARKET: 2
# EXCLUDED - D-1 GRADE: 2
# EXCLUDED - SOLD FROM CHURCH: 2
# valid: 2
# 2/3 NON ADJ PARCEL TR: 2
# 3/5 NON ADJ PARCEL TR: 2
# Not Open M: 2
# 2/5 NON ADJ PARCEL TR: 2
# 4/5 NON ADJ PARCEL TR: 2
# Included PP: 2
# Invstr To Invstr: 2
# 5/5 NON ADJ PARCEL TR: 2
# EXCLUDED - PURCHASED BY COUNTY: 2
# FOUND NO MLS. RJD: 2
# EXCLUDED - HAS SINCE SOLD/BAD SALE: 2
# WHY WOULD YOU SELL SOMETHING FOR HALF OF WHAT IT APPRAISED FOR. NOT A GOOD SALE. RJD: 2
# Inactivated parcel: 2
# EXCLUDED - SALE PRICE INCLUDES 3 PARCELS: 2
# INVALID unresolved problems with deedwork: 2
# FATHER TO SON: 2
# Not Rep Of Nghb: 2
# Included nc not yet completed: 2
# V - V: 2
# NO MONEY: 2
# LANDONLY: 2
# PARCEL 1 OF 3: 2
# Sold in 2021: 2
# has market value amenities not assessable: 2
# Sale Should Have Been Marked Invalid: 2
# Not 100% Complete For 2023: 2
# Sale is for out-buildings: 2
# 7-Giftornoconsideration;7-Giftornoconsideration: 2
# Receivers Deed: 2
# RELOCATION-PURCHASED: 2
# REALTIONSHIP: 2
# SOLD 2 X ONE YEAR: 2
# TWO SALES DISCLOSURES: 2
# 2 NON CONTIGIOUS PARCELS SOLD: 2
# SWMH - Nada Price: 2
# INTANGABLES INCLUDED NOT ASSESSABLE: 2
# $2 sale: 2
# Percent Complete: 2
# SOLD TWO TIMES IN ONE YEAR: 2
# LAND TO BLDR: 2
# coporate sale: 2
# 33-15-24-000-207.000-029 IS PRIMARY: 2
# SELLER WILL BE LEASING BACK FROM BUYER: 2
# Habitat For Humanity sale: 1
# Sale includes camper: 1
# Very high sale ($279/SF) out of area buyer: 1
# Historic Preservation Home.  Buyers and sellers both out of area: 1
# No MLS found.: 1
# TEAR DOWN OR REMO: 1
# TEAR DOWN?: 1
# VALUE SET BY PTABOA: 1
# Sale includes Liquor License, Inventory: 1
# WAS LISTED FOR 15/16K: 1
# Sale of unbuildable lake lot JMM: 1
# MINI WAREHOUSE SALE. STATE MANDATE TO ASSESS AT COST INSTEAD OF MARKET.: 1
# No MLS found///BOUGHT BY REALTOR. RJD: 1
# NEEDS WORK: 1
# THERE ARE NO PICS OF INSIDE OF HOUSE THIS TIME. EITHER HOUSE IS A DISASTER OR THE REALTOR UNDERPRICED THIS TERRIBLY. RJD: 1
# TEAR DOWN: 1
# See C59-2021-0008817, same sale: 1
# TEAR DOWN LAND SALE: 1
# NEEDS TLC: 1
# PREVIOUS VALUE SET BY APPEAL: 1
# BLC# 21738825 Listing includes Lots 42-45 equaling 2.84 acres.TOTAL 4 LOTS.SALE PRICE FOR ALL 4 LOTS $6500055-09-15-440-015.000-02055-09-15-440-016.000-02055-09-15-440-017.000-02055-09-15-440-018.000-020: 1
# GRANDFATHER TO GRANDDAUGHTER. PER OBIT OF GEORGELLA DAVIS. RJD: 1
# Building being razed: 1
# New Habitat for Humanity house: 1
# adjusted land influence factor: 1
# High sale ( $263/SF), small weekend log cabin, out of area buyers: 1
# Sold to surviving spouse: 1
# SALE WAS ORIGINALLY FROM 1/21/2022, BUT SECOND PARCEL WAS NOT INCLUDED ON FIRST DISCLOSURE OR SALE - SO THIS SALE ONLY INCLUDES SECOND PARCEL WITH SALES PRICE FOR BOTH PARCELS - MLS: 1
# LAND OF 48 ACRES FOR HUNTING - NO HOME: 1
# LAND ONLY - 1/2 INTEREST: 1
# Purchased and Razed Building/. - AVS: 1
# SHARES SALES PRICE WITH LOT 14 - SOLD TOGETHER - MLS: 1
# SALES PRICE LOW - MLS: 1
# Building new Habitat for Humanity Home: 1
# REMAINING 50% INTEREST SOLD ON THIS DISCLOSURE - MLS: 1
# Very high sale ($196/SF) for 2007 double wide on 1.06 acres: 1
# SALE OF 50% INTEREST ON THIS SALES DISLCOSURE - MLS: 1
# LAND ONLY - GOING TO BUILD: 1
# Converted to AirBNB: 1
# LAND ONLY - PLAN TO BUILD IN THE FUTURE: 1
# LAND ONLY - SOME TYPE 5 & DITCH: 1
# CHANGED TO I-D  -JE: 1
# Includes liquor license, inventory, fixtures: 1
# LAND ONLY HAS DITCH: 1
# LAND ONLY -LAYS WET IN AREAS: 1
# Complete rennovation in 2021, new roof, siding and windows: 1
# MLS WAS EXPIRED AT TIME OF SALE. HOUSE NEEDS COSMETICS AT LEAST. RJD: 1
# Trimmed - could not get this price if brand new.: 1
# POOR COND - TEAR DOWN: 1
# BLC# 21738825TOTAL 4 LOTS.SALE PRICE FOR ALL 4 LOTS $6500055-09-15-440-015.000-02055-09-15-440-016.000-02055-09-15-440-017.000-02055-09-15-440-018.000-020: 1
# Extremely high sale price; $48,300/ acre for 3.83 acres: 1
# adj property owner: 1
# BUYER SOLD THIS TO SELLER THEN BOUGHT IT BACK FOR LESS. RJD: 1
# Sale price in error, should probably be $100,000.  Questionable price since it is the same as 10/2020 sale.: 1
# Spec Home: 1
# 2009 L/C PAYOFF: 1
# Sold 11/24/21 for $34,000: 1
# Buyer lives across road: 1
# Individual sale; Yoder to Yoder and Raber: 1
# Buyer plans to raze house: 1
# Part of same sale above on separate disclosure.: 1
# Per listing, newly painted, new flooring, newer roof: 1
# Problems house gutted shortly after purchase: 1
# Out of area buyer.  Home was used as weekend cabin.  Paid premium for 10 acres with large stocked lake.: 1
# Sale includes solar panels, battery backup & electrical system: 1
# no home on this parcel: 1
# Property will be a church & transferred to the church: 1
# Will be guest house: 1
# Second home: 1
# Purchased to re-sell: 1
# Exchange of Properties: 1
# Unknowledgable Purchaser: 1
# Small ranch on slab, high sale for this area: 1
# High sale for this area, small 1961 home, 3 nearby sales in neigh $65,000 or less: 1
# New roof, new vinyl fence, new driveway, new bathroom flooring and all new wiring: 1
# Converting building from dance studio to union hall for United Auto Workers: 1
# Sold above listing, buyer and premium for the site. All 3.5 acres professionally landscaped with small lake: 1
# New roof, new flooring throught, new tiling in kitchen and bathrooms: 1
# 4 separate transfers, not market, between 8/29/22 and 3/15/23: 1
# New roof in 2021, new kitchen appliances and washer/dryer included in sale: 1
# Low sale of double wide, sellers were living in Missouri and needed a quick sale: 1
# High sale, small berm home: 1
# New roof, repainted interior, new carpeting throughout: 1
# New siding, roof, windows, drywall, sinks and Quartz countertops: 1
# Not realistic sale price.  Was listed with REMAX up to time of sale for $59,900: 1
# New roof in 2021, refinished hardwood floors, repainted interior: 1
# New metal roof, new French doors, new appliances, new patio in back: 1
# House undervalued on 2022 assessment, raising for 23/24: 1
# High sale, 1984 double wide manufactured home: 1
# Amematies included that are not assessable: 1
# Motivates seller (needs work): 1
# SON TO DAD: 1
# UNLISTED SALE. RJD: 1
# I - SOLD 3X: 1
# I - INTERIOR ISSUES: 1
# Very well maintained home but high sale for small ranch home: 1
# I - NOT LISED: 1
# I - TWO PARELS: 1
# I - SOLD TWIC E: 1
# PAID OFF ASSUMED LEIN OF $19000: 1
# NO MLS: 1
# handyman special: 1
# MLS # 21822794. THERE ARE THREE LOTS. ORIGINAL PRICE WAS 25000. STATES AT LEAST TWO BUILDING SITES. SELLER TOOK A LOSS IN 7 MONTHS IN AN UP MARKET. RJD: 1
# SALE OF UNBUILDABLE LOT FOR LAKE ACCESS: 1
# SALE OF UNBUILDABLE LOT: 1
# USE TOTAL OF: 1
# THIS INCLUDED THE PUTNAM COUNTY PARCEL ALL FOR THE SAME PRICE. RJD: 1
# EXPIRED MLS SHOWS HOME IS GUTTED: 1
# FOUOND NO MLS OR ZILLOW TYPE LISTING. SELLER IS OUT OF STATE. BUYER IS OUT OF TOWN. RJD: 1
# IV- HABITAT SALE TO OWNER/OCCUPANT: 1
# I - NOT LISED ON MARKET: 1
# INVALID - NON-MARKET TRANSACTION - UNUSUAL MRKT VARIABILITY: 1
# INVALID - NON-MRKT TRANSACTION - UNUSUAL MRKT VARIABILITY: 1
# invalid - contains market value amenities that are not assessable: 1
# invalid - has amenites that are not assessable: 1
# invalid - amenities are included that are not assessable: 1
# invalid - handyman special: 1
# INVALID - NON-MARKET TRANSACTION: 1
# INVALID - PER REASSESSMENT VISIT ON 7/6/22 (KS): 1
# INVALID - UNUSUAL MRKT VARIABILITY. NON-MRKT TRANSACTION: 1
# INVALID - TRANSFER TO HOLDING COMPANY.NON-MARKET TRANSACTION.: 1
# INVALID - NON MRKT TRANSACTION - SOLD FOR $7,100 (37%) LESS** THAN AV: 1
# No AV: 1
# INVALID - NON MRKT TRANSACTION - SOLD FOR $42,350 (31%) LESS** THAN AV: 1
# INVALID - NON-MARKET TRANSACTION - SOLD FOR $357,300 (36%) LESS** THAN AV.: 1
# INVALID - UNUSUAL MRKT VARIABILITY: 1
# INVALID - NO CONSIDERATION: 1
# INVALID - SALE PRICE NOT REFELCTIVE OF MRKT: 1
# Resale of property that was sold to nursing home to cover bills: 1
# land is land locked and not indictive of normal market value: 1
# Sale includes all equipment/ laundry and dry cleaning: 1
# Transfer between lenders: 1
# INVALID; UNKNOWN USE: 1
# LAND (1/2 ADJ PARCEL TR $15): 1
# LAND (3 PARCEL TR 5K): 1
# LAND (3/4 PARCEL TR 5K): 1
# LAND TO BUILD: 1
# LAND; 2/3 ADJ PARCEL TR: 1
# LAND; 4/4 ADJ PARCEL TR $4K: 1
# LAND-LOW PRICE: 1
# LOT TO BLDR: 1
# LOW PRICE = 34% OF A.V.: 1
# LOW PRICE = 40% OF A.V.: 1
# LOW SAE PRICE: 1
# Low sale amount: 1
# LSP: 1
# LSP= 27%AV: 1
# LSP= 49%: 1
# LSP= 51% V: 1
# INVALID; UNIQUE CHARACTERISTICS; ATRIUM: 1
# INVALID; SOLD AT TIME OF LISTING: 1
# INVALID; previously preplumbed bath is now finished: 1
# DAYS ON MARKET (283): 1
# BUYER IS ADJ PROPERTY OWNER 018-8153-5517: 1
# BUYER OWNS ADJ PROPERTY: 1
# BUYER/SELLER SAME: 1
# BUYER/SELLER SAME; 1/3 ADJ PARCEL TR: 1
# Close Sale: 1
# DAYS ON MARKET: 1
# DAYS ON MARKET (219): 1
# Grantee S/B Nicholas  Gaul & Sarah Hull: 1
# INVALID; PENDING AT PRINT: 1
# INVALD; PENDING AT PRINT: 1
# INVALID;  UNFINISHED ROOMS: 1
# INVALID; BOUGHT BY ACQUISITION COMPANY; PARCEL 2 OF 3: 1
# INVALID; BOUGHT BY POWER COMPANY: 1
# INVALID; BOUGHT BY POWER COMPANY FOR UTILTY PURPOSES: 1
# INVALID; PARCEL 2 OF 2   /  15-1182-61159; PER AUDITOR, NO FEE: 1
# INVALID; PENDING AT LIST: 1
# LSP=46%AV: 1
# NP 23/24: 1
# PARCEL 1 OF 2: 1
# POOR COND/GUTTED: 1
# INVENTORY INCLUDED: 1
# MUTI PARCEL DEAL: 1
# MOHOME INCLUDED PERSONSAL PROPERTY: 1
# DISTRESS SALE: 1
# ON MARKET 4YRS: 1
# PURCHASED TO RE-SELL: 1
# DEYSTROYED PROPERTY: 1
# PURCHASED FROM LANDLORD: 1
# c: 1
# SOLD TWIC: 1
# INCLUDED BUSSINESS: 1
# Signficiant changes made to property during appeal: 1
# Property purchased to keep competition out: 1
# Mini warehouse - lowest of three approaches not sale: 1
# Property was in need of extensive repair.: 1
# Owner deceased: 1
# N/C: 1
# For Sale sign in yard: 1
# PARCEL 1 OF 5: 1
# SOLD 3X ONE YEAR: 1
# Parcel 1of2 total of5 parcels on2 separateSDFs $382, total SP: 1
# PENDED AT TIME OF LISTING: 1
# PROBLEM DEED: 1
# PURCHASED BY TENANT: 1
# Purchased by tenant: 1
# SAME BUYER/SELLER: 1
# SELLER NP: 1
# Tusteee Deed: 1
# Sign inside of bldg: 1
# UNRECORDED L/C: 1
# VALID Parcel 2of3 total of 5 parcels on 2 separate SDFs $382,: 1
# VALID SALE; PARCEL 3 OF 4: 1
# This is a valid sale we used BUT the SDFID in our system is C75-2021-0009203: 1
# 1031 exchange: 1
# Corrected Deed: 1
# Highly modivated seller: 1
# 9/13 NON ADJ PARCEL TR: 1
# 8/13 NON ADJ PARCEL TR: 1
# 7/8 ADJ PARCEL TR: 1
# Included - our sale price on sales disclosure is 148,000: 1
# Entire interior repainted, new listing, flooring, replacement windows, vinyl siding: 1
# RES PARCEL IN COMM NHBD: 1
# BUILDING NEEDS MAJOR REPAIRS, SELLER JUST WANTED TO GET RID OF IT & FEELS $500 IS ALL ITS WORTH.: 1
# LOT IS SMALL, NOT BUILDABLE: 1
# FOUNDATION IN BASEMENT WAS CRUMBLING & NEEDED A LOT OF WORK. BUYER PAID TO HAVE THE BASEMENT FIXED SO THE SELLER COULD SELL THE HOUSE TO THE BUYER.: 1
# House was listed for $125,000, Carpenter Realtor, sold for $25,000 over listing: 1
# Commissioner Sale: 1
# SIGNIFICNT CHANGES  AND  NOW OWNER OCCUPIED: 1
# Includes shop equipment, fixtures, inventory: 1
# SIGINIFICANT CHANGES: 1
# SignificantAmountofPersonalProperty: 1
# NONHOUSE: 1
# SIGNFICIANT CHANGES: 1
# SIGNIICANT CHANGES: 1
# SIGNIFIGANT CHANGES: 1
# INVALID PER BB  PLANNED DELVELOPMENT: 1
# Discrepancy in actual sale price. Price also stated as $104,900 by realtor: 1
# Sherif's sale: 1
# MUTLI PARCEL SAALE: 1
# Exist in Sales File, did NOT match up with sale in Proval: 1
# Interior of building gutted, shell only: 1
# Includes Travel Trailer: 1
# Not offerd to public: 1
# Sold 3 time in one year: 1
# Relo sale: 1
# Sale includes NC not 100% complete: 1
# Price included NC not yet completed: 1
# TRANSFER TO T MUNICIPALITY: 1
# 12 lot sale on 2 disclosures ( See above): 1
# Very low sale, six 60 x 110 lots, out of area seller: 1
# Not legitimate price; $175,000 1995 ranch style home: 1
# Sold to library, building razed for 22/23: 1
# House razed: 1
# Converted to a house for 22/23: 1
# House razed for 22/23: 1
# 12 lot sale on 2 disclosures ( See Below): 1
# MUTLIPE SALES SAME YEAR: 1
# 1/13 NON ADJ PARCEL TR: 1
# 7/13 NON ADJ PARCEL TR: 1
# 4/13 NON ADJ PARCEL TR: 1
# 2/2 non adj parcel tr: 1
# 2/3 ADJ PARCEL TR $117.5K: 1
# 2/3 ADJ PARCEL TR $37.5K: 1
# 2/6 NON ADJ PARCEL TR: 1
# 3 parcels sold $35,: 1
# 3/13 NON ADJ PARCEL TR: 1
# 4 parcel sold: 1
# 4/5 NON ADJ PARCEL TR $8K: 1
# 2/2 ADJ PARCEL TR; 255K: 1
# 4/6 NON ADJ PARCEL TR: 1
# 4/8 ADJ PARCEL TR $15K: 1
# 5/13 NON ADJ PARCEL TR: 1
# 5/6 NON ADJ PARCEL TR: 1
# 6/13 NON ADJ PARCEL TR: 1
# 6/187 ADJ PARCEL TR 4.6M; BUYER IS HOTEL OWNER: 1
# 6/6 NON ADJ PARCEL TR: 1
# 2/2 ADJ PARCEL TR; LSP= 26%AV: 1
# 2/2 ADJ PARCEL TR; 225K: 1
# 1/2 ADJ PARCEL TR: 1
# 13/13 NON ADJ PARCEL TR: 1
# 1/2 ADJ PARCEL TR $38483 3/6 NON ADJ PARCEL TR: 1
# 1/2 ADJ PARCEL TR $7K; LAND: 1
# 1/5 NON ADJ PARCEL TR $8K: 1
# 1/6 NON ADJ PACEL TR: 1
# 1/7 ADJ PARCEL TR; VL; SALE TO CITY: 1
# 11/13 NON ADJ PARCEL TR: 1
# 12/13 NON ADJ PARCEL TR: 1
# 2 pacels sold 18-2119-4388 $2, (Low price 33%of AV): 1
# 2/2 ADJ PARCEL TR 1/2 NON ADJ PARCEL TR: 1
# 2/13 NON ADJ PARCEL TR: 1
# 2/2 ADJ PARCEL 2/2 NON ADJ PARCEL TR: 1
# 2/2 ADJ PARCEL TR: 1
# 2/2 ADJ PARCEL TR $216K: 1
# 2/2 ADJ PARCEL TR $4.6K: 1
# 2/2 ADJ PARCEL TR $85K: 1
# 2/2 ADJ PARCEL TR $8K: 1
# Cabin only.  Carrying changes from PTABOA final: 1
# Includes Tenants: 1
# New flooring in all 3 bedrooms and both bathrooms,  high sale for 1989 double wide: 1
# EXCLUDED - INCLUDES PERSONAL ITEMS: 1
# EXCLUDED - JUNK LAND: 1
# EXCLUDED - CELL TOWER ON PROPERTY: 1
# EXCLUDED - NO ACCESS: 1
# EXCLUDED - GRADE IS A D-1: 1
# EXCLUDED - INVESSTMENT: 1
# EXCLUDED - NEW CONTRUCTION AFTER PURCHASE: 1
# EXCLUDED - GUARDIANS DEED: 1
# EXCLUDED  - CLERICAL ERROR ON SALES DISCLOSURE: 1
# INCLUDED - SALE PRICE WAS ENTERED INCORRECTLY ON DISCLOSURE ($3,150): 1
# EXCLUDED - SOLD FOR $14,000: 1
# EXCLUDED - NO ACCESS/TRESSPASSING: 1
# PERSONAL USE: 1
# NO HEAT/ELECTRIC: 1
# Sale between father and daughter: 1
# BUYERS DAUGHTER WILL BE LIVING THERE. SELLER MOVED OUT OF STATE AND WANTED TO GET RID OF.: 1
# SALE INCLUDED EQUIPMENT: 1
# Sale half of assessment - not used: 1
# EXCLUDED - SOLD FOR $10 & UNDER: 1
# EXCLUDED - SOLD FOUR TIMES IN ONE YEAR: 1
# OUT OF STATE SELLER: 1
# EXCLUDED - SOLD AND BOUGHT BY TO OUT OF STATE COMPANY: 1
# INVALID SALE  SIGNIFICANT AMOUNT OF PURCHASE PROPERTY  PURCHASED BY DOLLAR GENERAL: 1
# INVALID SALE  SALE INCLUDED FRANCHISE OF KFC: 1
# INVALID SALE  SALE AMOUNT LEE THAN MINIMUM ;IN NEED OF MANY REPAIRS: 1
# INVALID SALE - 1880 LOG HOME - COULD NOT REACH THAT PRICE IF NEW: 1
# EXCLUDED - UNKNOWN SALE: 1
# EXCLUDED - HAS SINCE SOLD IN 2023: 1
# EXCLUDED - 2 DISCLOSURES 1/4 INTEREST: 1
# EXCLUDED - 2 DISCLOSURES AND 1 DEED ON THIS PARCEL STATE FEE WAS COLLECTED ON 1ST DISCLOSURE  THIS IS 3/3RD INTEREST: 1
# EXCLUDED - SOLD FOR $15,000: 1
# EXCLUDED - SELLER NEVER LIVED IN HOME: 1
# EXCLUDED - CORRECTION OF RECORDING ERROR: 1
# EXCLUDED - SOLD FOR 15K: 1
# EXCLUDED - BUYER/SELLER OUT OF STATE-COULD NOT VERIFY SALE: 1
# EXCLUDED - SOLD FOR 4351: 1
# EXCLUDED - PURCHASED FOR INVENTORY: 1
# EXCLUDED - 3 PARCELS INCLUDED IN SALE: 1
# EXCLUDED - 5 PARCELS IN SALE PRICE: 1
# SELLER STATED SHE BOUGHT CHEAP BUT IT BECAME TOO MUCH FOR HER SO SHE SOLD IT QUICKLY TO GET RID OF IT.: 1
# OUT OF TOWN BUYER: 1
# INVALID- SIGNIFAICANT CHANGES: 1
# Sale under value for Nbhd: 1
# Correct Mktmodel: 1
# See the ratio: 1
# Sigificant Changes: 1
# Value set by legislation: 1
# 50% Intrest: 1
# Accessory Parcel: 1
# SIGNIFICANT PERSON PROPERTY/INVENTORY IN SALE: 1
# Sale crosses TWSP lines: 1
# SOLD TO GRANDSON: 1
# CREATED PARCEL PER DEED & MAP: 1
# Sale included a PPMH: 1
# Valid 2021: 1
# sold for highway purposes: 1
# Parcel deaded: 1
# Parcel not in Proval: 1
# In Rati Study as C29-2022-0005354: 1
# Auditor rejected document/wrong legal: 1
# PROJECT HOUSE; PER PHONE CALL W/ SELLER: HOME WAS COMPLETELY GUTTED & NEEDS COMPLETED: 1
# PROPERTY WAS A QUICK SALE & NEEDS LOTS OF REPAIR PER SELLER: 1
# Relo Company: 1
# 599 SALE WITH VP COND; NOT INDICITIVE OF NBHD: 1
# Changed afte sale: 1
# Sale Included PP: 1
# NC: 1
# This one should have been charged a sales disclosure fee. New person in Assessor's office marked wrong box.: 1
# BUYERS SAID THAT HOME NEEDS SOME REPAIRS: 1
# Home in need of extensive repair due to rupture of a water pipe and flooded interior: 1
# Seller purchased property for $10,000 in march of 2021-: 1
# SALES HAS 3 SALES DISCLOSURES: 1
# SALE INCLUDED 3 SALES DISCLOSURES: 1
# HUSBAND DIED AND SHE ISN'T ABLE TO TAKE CARE OF 2 HOMES: 1
# SELLER HAD PURCHASED IN 2020 FOR EXACT SAME AMT THAT HE SOLD IT FOR: 1
# PARCEL WAS GIFTED TO SELLER: 1
# SALE INCLUDES #010-103054-01 & #010-103084-01; RES 7 COM SOLD TOGETHER: 1
# SALE AMOUNT LEAA THAN MIN; NBHD RANGE 65K-250K: 1
# INCLUDES #010-133018-00, #010-133019-00 & #010-125000-00; NO INVENTORY INCLUDED ; SALE AMOUNT WAY OVER VALUE FOR KIT BUILDING: 1
# SALE AMOUNT INCLUDED PROSPECTS OF CHANGING BUILDING: 1
# BUILDING IN P COND; SALE FOR LAND?: 1
# INVALID SALE  SOLD TWICIE IN ONE YEAR: 1
# SPILT PARCEL: 1
# Not market sale, $100,000 house: 1
# THE SDFID # IS WRONG - SALE WAS USED UNDER SDFID #C07-2022-0001111: 1
# Changed values (data entered after pull): 1
# Lauren changed in system after import: 1
# Sold to tenant: 1
# Sales disclosure form unavailable: 1
# Old gas station - already applied obsolescence: 1
# Corrected Sale ID per Lauren: 1
# State sale to individual - no road access: 1
# Sale not submitted from auditor's office in time to be validated before 2024: 1
# Sale not submitted from auditor's office in time to be validated before 2025: 1
# Gift or no consideration: 1
# Sold in 2019 for $160,000 with no changes: 1
# Seller & buyer are same individual: 1
# Land and Lake carry value - cannot adjust enough: 1
# Exchange of parcels: 1
# PUT HOUSE IN FAIR COND: 1
# ADJUSTED LAND INFLUENCE: 1
# NEW BUILDING SINCE SALE: 1
# Downtown building needing lots of work: 1
# INVALID - LETTER OF CONDEMATION: 1
# SELLER LIVES OUT OF STATE - NEEDED TO DISPOSE OF PROPERTY: 1
# Home listing and sale includes a relocation clause.: 1
# Interior not all complete at time of sale: 1
# mutiproperty sale: 1
# Price recuction: 1
# Last Lot in Subdivision: 1
# one of the last remaining lots, selling for premium: 1
# INVALID - MOSTLY LAND SALE: 1
# INVALID - FUTURE VALID SALE SAME YEAR: 1
# INVALID - LARGE AMOUNT OF LAND: 1
# Home VP, sold for land: 1
# INVALID - EXCESS RES: 1
# structures not habitable: 1
# TEMPORARY TRANSFER: 1
# INVALID - PORTFOLOIO SALE: 1
# NEW OWNER IS BUILDING A HOME: 1
# foundation issues present at time of sale: 1
# INVALID - NON MARKET SALE PER DAN: 1
# INVALID - VALID LAND: 1
# SOLD TWINCE IN ONE YEAR.: 1
# PROPERTY TO BE USED FOR HUNTING ONLY, NOT RESIDENCE: 1
# BUILDING A HOUSE: 1
# RALTIONSHIP: 1
# 75% OBS REM: 1
# 0 DAYS ON THE MARKET: 1
# NO MARKETING TIME: 1
# SALES PRICE: 1
# ONLY 2 DAYS ON MARKET: 1
# HAS RESTRICTING FOR SALE: 1
# NOT FULL DAY ON MARKET: 1
# BOUGHT TO TEAR DOWN: 1
# BUYER AND SELLER ARE THE SAME: 1
# ONLY TWO DAYS ON THE MARKET: 1
# TWO DAYS ON THE MARKET: 1
# UPPER END HOME: 1
# NO HOME ON THIS PARCEL JUST BUILDINGS: 1
# INVALID:SOLD TO TENANT: 1
# INVALID:HANDYMAN SPECIAL (GOOD BONES): 1
# INVALID-LANDLOCKED NON-BUILDABLE LOTS: 1
# Consideration includes purchase of easement: 1
# SIGNFICANT CHANGE: 1
# Parcel number is no longer an active number: 1
# MAJOR CHANGES WERE MADE ON REASSESSMENT: 1
# ORIGINALLY MARKED INVALID -HOTEL: 1
# INCLUDES DOUGHNUT SHOP PROPERTY: 1
# DEED STATES LAND CANNOT BE BUILT UPON PER U.S. AIR FORCE: 1
# TOO LOW FOR RETAIL IN THAT AREA: 1
# PURCHASED LAND W/BILLBOARD: 1
# I-T ONLY MH PARK SALE: 1
# SOLD W/COMM: 1
# INCLUDES EQUIPMENT FOR CAR WASH: 1
# PUT HOUSE IN VP COND: 1
# CHANGED EFP TO OFP: 1
# SALE PRICE DOES NOT REPRESNET PROPERTY VALUE. MAY HAVE BEEN DISSOLUTION OF PARTNERSHIP. NO CONTACT: 1
# TWO PROPERTIES PURCHASED FOR ONE PRICE - NO DESIGNATED PRICE ON INDIVIDUALS: 1
# PROPERTY SOLD TO REALTOR FROM WIDOW DISPOSING OF PROPERTIES: 1
# PUT HOUSE IN FAIR COND. BUYER IS SELLER'S SON. SELLER SAID HOUSE NEEDS A LOT OF REPAIRS: 1
# I-L / I-O  SELLER NEEDED TO DISPOSE OF PROPERTY ASAP TO MOVE OUTOF STATE: 1
# SPOUSE PASSED AWAY.  WIDOW NEEDED TO SELL: 1
# DUPLCIATE SALE: 1
# LEASBACK SALE: 1
# Parcel # not active: 1
# Sale well over Nghb. median: 1
# Auditor rejected deed/legal: 1
# Comparable: 1
# Changing To Food Service: 1
# Mls #500313: 1
# Not A Sale, Name Chg: 1
# Per Mls, Sold On 12/1/21 For $367,500, 3 Dom: 1
# Sold Significantly Under Appraisal: 1
# Mls # 495290 / Not Rep Of Nnghbd Values: 1
# Duplicte Of Sale #164672: 1
# Per Phone Call With Seller On 12/15/21, The Sale Price Was Lower Than The Appraisal Value: 1
# Adj Property Owner: 1
# Amended Disclosure: 1
# Sellers Are Heirs Getting Rid Of The Property: 1
# Seller Is An Heir Getting Rid Of The Property: 1
# Could Not Confirm If Pp Was Included: 1
# Va Sale: 1
# Previous Sale Was Gift Deed: 1
# Defunct Gas Station: 1
# Sherriff Sale: 1
# Not Rep Of Nghbnot An Open Mrkt Sale: 1
# Sold To Gvt Entity: 1
# House Unlivable: 1
# Per Phone Call With Seller On 9/28/21, The Buyer Is His Daughter.Sale Price Was Significantly Below The Appraisal Value.: 1
# Gardianship: 1
# Sale Price Not Within Range Of Nearby Comparable Sales: 1
# Remains Of Old Home Exist On Parcel: 1
# Special Deed, Seller Retains Interest: 1
# Bought From Church: 1
# Questionnaire Sent 8/20/21: 1
# Not An Open Mrkt Sale: 1
# Called Buyer2Nd Od 3 Sales On This Property So Far This Year: 1
# Call Made To Seller: 1
# Building Spec Home: 1
# Sale Price Well Below What Comparable Sales Suggest The Value Should Be: 1
# Mls 496872: 1
# Seller Just Bought In March 2021: 1
# Not In Line With Comparable Sales: 1
# Special Circumstancessubsequent Sale: 1
# Mls #500476: 1
# Buyer And Seller Are Same Signer.(Buyer Plans To Builda 249,000 Sq Ft Spec Industiral Building On This Parcel.): 1
# Sold A Month Later For Same Price: 1
# Sellers Were Heirs Getting Rid Of The Property: 1
# No Validation Codes: 1
# Sold after house burned: 1
# Sold for $1,000 7/9/20, value lowered by PTABOA: 1
# Property sold for $203,514 12/3/20: 1
# Sold building to tenant: 1
# Parcel inactvie for 22/23: 1
# Sold 9/25/20 for $3,400,000; includes franchise rights, equipment, inventory: 1
# High sale for unusual design and location of home: 1
# Value changed with PTABOA final: 1
# High sale, sold for $11,000 over listing: 1
# Major structural changes to foundation and crawl to repair/prevent moisture issues: 1
# Buyer listed as 9 years old; signed by AIF: 1
# Well maintained but high sale price for 2001 double wide: 1
# Sold for $160,000 higher than 2020 sale and $270,000 higher than 2018 sale: 1
# House razed for 23/24: 1
# New double wide for 23/24: 1
# Turnkey sale, included all body shop equipment and spray booths: 1
# House burned , 137R filed: 1
# New roof and hardwood floors in 2021, extensive new landscaping: 1
# New Jiffy Lube building for 22/23: 1
# Buyer lives directly across street: 1
# Just Sold In 2023: 1
# New laminate flooring throughout, repainted, new granite countertops, new water heater, new appliances: 1
# Sold To Bp: 1
# Owner Deseased: 1
# Not Withing Range Of Comparable Sales In Nbhd: 1
# Re-Recording: 1
# Seller Contacted Buyer: 1
# Sale Pending 2.16.23 $255,000: 1
# Re-Recorded From May Sale: 1
# Not Rep Of Nghb Valuesnot An Open Mrkt Sale: 1
# Buyer/Seller Associated Companies: 1
# HOUSE TORN DOWN AFTER PURCHASE: 1
# Includes 3 Way Liquor License: 1
# INCLUDES PERSWONAL PROPERTY: 1
# Valued per IC 6-1.1-4-42: 1
# PRIVALE SALE: 1
# SOLD TWO TIMES - ONE YEAR: 1
# SOLD TWO TIMES - ONE YEAR (2ND SALE IS 7/21/22): 1
# Sold to tenants (Motorcycle Club): 1
# Subsequent Sale In 2021 Sale Id 163374: 1
# Co-Owner Signing Over His Interest To The Buyer: 1
# Buyer Used To Own Property With Seller: 1
# I-O  PROPERTIES WILL BE USED RESIDENTIALY IN THE FUTURE: 1
# PER NOTE- INCAMA INCORRECTLY PRICING EXHORBITANT SQFT: 1
# BUILDING RAZED AFER SALE: 1
# SALE PRICE IS FOR TWO NON CONTIG PARCELS: 1
# SALE PRICE IS FOR TWO NON-CONTIG PARCELS: 1
# PREVIOUS OWNER BUYING BACK PROPERTY: 1
# One sale price for six parcels: 1
# I-O  PRICE INCLUDES PURCHASE OF FRANCHISE RIGHTS: 1
# MFG HOME SKEWED SALES: 1
# I-E  PURCHASED TO BE USED AS RESIDENTIAL: 1
# Sale of Subsidized units - Law prevails over sale: 1
# Purchase to Fip: 1
# LAND IN STATE PROGRAM: 1
# Very Large Home On Over 5 Acres, This Price Does Not Match The Market.: 1
# Odd Shaped Parcel Not The Norm: 1
# Cannot Confirm Sale Price, Area Land Values Alone Are Significantly Higher: 1
# VancantLand: 1
# SheriiffSale: 1
# One party sold and closed: 1
# I-4  SOLD TO CITY OF KOKOMO: 1
# Sale Price Is Significantly Below What Comparable Sales Suggest The Value Should Be: 1
# MUCH WORK NEEDED: 1
# Easements or right-of-way grants: 1
# INCOMING PRODUCING PROPERTY: 1
# 33-12-14-340-185.000-016: 1
# 2ND SALE IN 3 MONTHS: 1
# 33-16-26-310-348.000-029 is primary: 1
# 33-07-19-430-113.000-017: 1
# 33-03-27-000-202.000-021: 1
# 33-17-17-431-428.000-026: 1
# 33-12-14-220-173.000-016: 1
# 9/22/22 corrected sale price to $27,000 from $169,900  (title company error): 1
# ALL BUILDINGS VERY POOR COND: 1
# VERY POOR COND: 1
# ONE-PARTY SALE: 1
# invetment property: 1
# INCLUDES PARCEL 301-017: 1
# Land still ran as woods - no home yet: 1
# SALE PRICE INCLUDES NON-CONTIG PARCEL 34-10-06-331-019.000-002: 1
# O,Orecording issue: 1
# SAME SELLER AND BUYER GORUP (MARY LOUISE MILLER): 1
# ENVIRONMENTAL ISSUES WITH LAND, RESTRICTING AVAILABILITY: 1
# SALE INCLUDED PARCELS IN MARSHALL COUNTY: 1
# SALE PRICE INCLUDES A NON-ASSESSABLE PARK MODEL MH: 1
# Settlement Of A Disputed Claim: 1
# No Mls: 1
# Bought And Sold Soon After: 1
# Sold Next Day: 1
# Mls #480027 Sold Date In Mls: 09/25/2020: 1
# Not Within Market Valuesent Questionnaire: 1
# Sale Price Is Significantly Below What Comparable Sales Suggest The Value Should Be.: 1
# Copy Filed In Error Per Preparer 7/2/21 Nt: 1
# Heirs Getting Rid Of Property: 1
# Inv/Inv: 1
# Buyer Sold 13 Days After Purchase: 1
# Copy Filed In Error Per Preparer -Deanna Griggs 7/1/21 Nt: 1
# New In Ground Pool 2022: 1
# Builidng Being Finished: 1
# Pp Included In Sale: 1
# Sale Price Is Significantly Below What Comparable Sales Suggest It Should Be: 1
# INCLUDED A BOAT: 1
# BUYER AND SELLER HAVE SAME PO BOX # (SEE PRC & DISCLOSURE): 1
# BUYER IS EX WIFE TO SELLER: 1
# NEW BUYER OVER-PAID JUST TO GET THEM OUT OF THE NBHD.  HOARDERS AND YELLED AT THEIR OWN CHILDREN ALOT.  HAD 5 CATS AND 1 DOG IN HOUSE.  NEEDS GUTTED TO STUDS.  NEW OWNER HAS BLEACHED THE CEMENT FLOORS AND STILL CAN'T GET THE SMELL OUT.: 1
# SOLD 16 DAYS LATER FOR SAME AMOUNT: 1
# SOLD W/ 7-49-63 - TWO DISCLOSURES TOTAL SALE PRICE $33000: 1
# PURCHASED BY LAKEFRONT PROPERTY OWNER: 1
# YOGI LOT: 1
# THERE IS NO WAY TO JUSTIFY THIS SALE PRICE: 1
# SALE OF UNDIVIDED 1/2 INTEREST: 1
# THE LADY THAT WORKS FOR KS & F TOLD ME THAT THE HOUSE HAS BEEN GUTTED FOR YEARS BUT NO ONE HAS CALLED TO NOTIFY US ABOUT THIS.: 1
# SOLD 1 MONTH LATER FOR $340,000: 1
# MENNONITE MUTUAL IS TAKING TITLE TO PROPERTY AND WILL THEN TRANSFER TO NEW OWNER - NOT A SALE: 1
# MICHELLE HARMEYER IS A SISTER OF SHARI LAMBERT (DECEASED): 1
# SOLD 8 DAYS LATER FOR $20,000: 1
# TRANSFER TO RELO COMPANY - THEN RELO TRANSFERS TO NEW OWNER: 1
# DAD SELLING TO SON: 1
# SALE BACK TO ORIGINAL OWNER FOR SAME PRICE: 1
# SOLD 4 MOS LATER FOR 352,000: 1
# SWAPPED HOUSES WITH NEIGHBOR: 1
# Seller not knowledgeable of the market: 1

# %%
process_file("tippecanoe/Combined_Reconciliation_2024_2.csv")
# Out:
# Results for tippecanoe/Combined_Reconciliation_2024_2.csv:
# Unique Reasons with Counts:
# No house included in sale: 28
# Invalid-Pending at listing: 16
# Relocation: 15
# INSUFFICANT SALES: 9
# per legislation, lowest of 3 approaches to value was used: 7
# land order done this year: 6
# TEMPORARY TRANSFER: 6
# Per legislation, lowest of three approaches used: 5
# Percent Complete: 5
# Dulicate Sale: 5
# Insufficant Imp Comm Sale for a Study: 4
# Sale involved PP: 4
# House Incomplete: 4
# Support land: 4
# Insufficant Sales for Imp Ind Study: 4
# RELOCATION SERVICES: 4
# 599 sale.: 4
# Invalid-New Contruction: 4
# Value set by legislation: 4
# * INVALID - SOLD BEFORE LISTED *: 3
# RELOCATION SALE: 3
# * INVALID - LAND ONLY *: 3
# Habitat home sale.: 3
# SOLD SIGNIFICANTLY HIGH THAN ASKING PRIVE: 3
# INVALID; PENDED AT LIST: 2
# RESURVEY: 2
# GOING CONCERN VALUE INCLUDED: 2
# Invalid-Sold at listing: 2
# TEAR DOWN: 2
# LAND ONLY: 2
# Invalid Sale-No Consideration: 2
# Same buyer seller in two months: 2
# Per legislation, lowest of three approaches to value used: 2
# Separate disclosures: 2
# Has since sold: 2
# No MLS found: 2
# REALTOR: 2
# significant pp not disclosed on sdf: 2
# Value set per appeal: 2
# Seller not Knowledgeable of Market: 2
# Value Set by legislation: 2
# 2022 Sale: 2
# Commissioners Sale: 2
# Secretary of Veteran's Affairs: 2
# Lakefront Property: 2
# Commissioner Sale: 1
# Part of larger sale: 1
# adjusted land influence factor: 1
# SALE WAS ORIGINALLY FROM 1/21/2022, BUT SECOND PARCEL WAS NOT INCLUDED ON FIRST DISCLOSURE OR SALE - SO THIS SALE ONLY INCLUDES SECOND PARCEL WITH SALES PRICE FOR BOTH PARCELS - MLS: 1
# Bought of market by Realtor: 1
# Property being sold as needs work: 1
# signficant changes: 1
# Signficant changes: 1
# LIQUOR LICENSE INCLUDED: 1
# SignificantAmountofPersonalProperty: 1
# INVALID; SOLD AT LISTING: 1
# land is land locked and not indictive of normal market value: 1
# No MLS found. Unadvetised sale of new parcel: 1
# Sold to Granddaughter, per obituary of Gayle Ream: 1
# INVALID; GRADE IS WRONG: 1
# PART OF A NON ADJ PARCEL TR: 1
# SELLER WILL REMAIN IN PROPERTY: 1
# Bought by Utility: 1
# Cost Approach: 1
# 599 PCC-ONLY DET GAR & SHED.: 1
# Building home: 1
# CABIN IN NEED OF A LOT OF REPAIR: 1
# ALL BLDGS IN VP COND: 1
# Not transferred, error in legal: 1
# 3 SDF's DUE TO ALL PARCELS NO CONTIGUOS.: 1
# Easement: 1
# HOUSE IN NEED OF LOTS OF WORK AND REPAIRS.: 1
# NOT VALID DUE TO WORK THAT NEEDS TO BE DONE & NUMEROUS REPAIRS NEEDED.: 1
# NEEDS LOTS OF WORK AND REPAIRS: 1
# NEEDS WORK AND REPAIR: 1
# NEEDS LOTS OF WORK & REPAIRS: 1
# HOME NEEDS LOTS OF REPAIRS: 1
# TEARING ALL STRUCTURES DOWN: 1
# HOUSE IN NEED OF A LOT OF WORK, SELLER DIDN'T WANT IT ANYMORE: 1
# High sale for small 2-bedroom, 50 year old ranch: 1
# Very high sale.  Plain older ranch home, 1,288 SF, sold for $214/SF: 1
# lowest of 3 value per legislation: 1
# Low sale, seller in Texas, buyer in South Carolina: 1
# lowest out of the thre approaches to value: 1
# Property is part of a MH park, will use the lowest of 3 approaches to value: 1
# INVALID; UNIQUE CHARACTERISTICS, FOUNTAIN: 1
# SOLD BEFORE LISTING: 1
# Sale price included the cost of constructing a new building in 2024: 1
# Sale includes 15 acres of tillable land: 1
# MH Sound Valued using NADA: 1
# Corrected Deed: 1
# P.P MOHOME: 1
# MOVING TO NURSING HOME: 1
# ON MARKET TOO LONG: 1
# OUTLIAR: 1
# P.P. MOHOME: 1
# EASEMENT ONLY: 1
# Gift or No Consideration: 1
# SOLD BEFORE LISTED: 1
# * NON MARKET*  SOLD BEFORE LISTED: 1
# Invalid-Seller offers $5000 towards closing.: 1
# * INVALID - SOLD BEFORE LISTED*: 1
# * INVALID - * BASEMENT*  ( LOWER LEVEL ) FINISHED*  NEEDS REVIEWED: 1
# CELL TOWER INCLUDED IN SALE: 1
# * INVALID - PTRIVATE SALE *: 1
# * INVALID - PRIVAT SALE *: 1
# * NON MARKET *: 1
# Owner deceased: 1
# RERECORDING OF PARCEL THAT WAS MISSED ON ORIGINAL DEED.: 1
# Major Changes to property: 1
# House not 100% complete: 1
# House not picked up: 1
# Not market value: 1
# Significan Change. Was in wrong NBH: 1
# PAY OFF LAND CONTACT: 1
# NOT VALID: BUYER PURCHASED010-1058-1415: 1
# INVALID; PENDED AT PRINT: 1
# Invalid-Pending at listing.: 1
# Invalid-new contruction: 1
# Invalid-Seller offered credit towards home: 1
# Invalid-Pending at Print: 1
# invalid; 01/03/24 VV: 1
# NP 24/25: 1
# LOW SALE AMOUNT: 1
# RE-RECORDED DEED TO MISHAWAKA DRYWALL: 1
# Dumped "junk lots": 1
# PURCHASED FOR FUTURE BUILD: 1
# Invalid-Vaant Land: 1
# INVALID; BUYERS USED TO LIVE IN UNIT 7: 1
# SPECIAL WD: 1
# I - SALE FROM FANNIE MAE: 1
# Invalid-Never hi the market: 1
# CORRECTIVE DEED: 1
# NOT VALID: BUYER OWNS 018-6038-1217: 1
# Incorrect entry sale deleted: 1
# Invaalid-Pending at listing: 1
# Quick sale (Relocation): 1
# invalid-pending at listing: 1
# Invalid_Triplex: 1
# Invalid-: 1
# Invalid-Consessions paid: 1
# Invlaid-Pending at listing: 1
# LOW SALE PICE: 1
# ammenities and non-tangilbes not assessable: 1
# Buying out Co-owner: 1
# INVALID CONTACT: 1
# I-T ONLY MH PARK SALE: 1
# I-L / I-O  SELLER NEEDED TO DISPOSE OF PROPERTY ASAP TO MOVE OUTOF STATE: 1
# SOLD W/COMM: 1
# NO MONEY: 1
# BUYER WALKED AWAY NEVER TOOK POSSESSION: 1
# NO HOUSE ON THIS PARCEL: 1
# STUDENT BUILT: 1
# SOLD SECOND DAY ON MARKET: 1
# INTANGABLES INCLUDED: 1
# SOLD TO TENANT: 1
# GOING CONCERN INCLUDED IN SALE: 1
# INTERIOR AMMENITIES ARE SUPER FOR THIS HOUSE: 1
# INVALID MUTIPLE PARCELS: 1
# obsol recently applied due to repairs needed: 1
# PURCHASED LAND W/BILLBOARD: 1
# Sold to tenant: 1
# Sig Changes: 1
# Includes liquor license: 1
# Under 10,000/seller is great aunt to buyer: 1
# Holding company: 1
# Not arm length: 1
# Parcel deleted: 1
# Sold from city: 1
# Cell tower: 1
# Wrong price recorded: 1
# Guardians deed: 1
# Junk land: 1
# Warranty deed: 1
# I-L / I-O       PROPERTY UNDER APPEAL AT TIME OF SALE: 1
# PURCHASED WITH PP: 1
# sale involved 2 homes: 1
# Sale did not include new mh moved in: 1
# destressed sale: 1
# 137  filed: 1
# House relisted for higher value: 1
# Quick sale: 1
# House needs work: 1
# Price reduction: 1
# Specialty Property: 1
# INVALID - BOARDED UP: 1
# INVALID-LAND/FUTURE BLD: 1
# Value must be lowest of three, Ind cost is not accurate: 1
# Sold for the land: 1
# RESIDENTIAL BUILDING LOT: 1
# ORIGINALLY MARKED INVALID - NON MARKET SALE: 1
# Right of way grant: 1
# INCLUDES EQUIPMENT FOR CAR WASH: 1
# Land and Lake carry value - cannot adjust enough: 1
# Seller & buyer are same individual: 1
# PUT HOUSE IN VP COND: 1
# PUT HOUSE IN FAIR COND. BUYER IS SELLER'S SON. SELLER SAID HOUSE NEEDS A LOT OF REPAIRS: 1
# SALE PRICE DOES NOT PUT VALUE ON STRUCTURES: 1
# SELLER FROM OUT OF STATE, NEEDED TO LIQUIDATE: 1
# SELLER MOVED OUT OF STATE, NEEDED TO LIQUIDATE: 1
# SOLD TO HOLDING COMPANY: 1
# SALE PRICE DOES NOT REPRESNET PROPERTY VALUE. MAY HAVE BEEN DISSOLUTION OF PARTNERSHIP. NO CONTACT: 1
# CHANGED EFP TO OFP: 1
# PROPERTY SOLD TO REALTOR FROM WIDOW DISPOSING OF PROPERTIES: 1
# TWO PROPERTIES PURCHASED FOR ONE PRICE - NO DESIGNATED PRICE ON INDIVIDUALS: 1
# SPOUSE PASSED AWAY.  WIDOW NEEDED TO SELL: 1
# Out of state sale: 1
# Seller has interest: 1
# Junk property: 1
# SOLD TWO TIMES IN ONE YEAR.: 1
# Adj. Property Owner: 1
# New const. in progress: 1
# Non- Market Sale: 1
# Realationship between buyer and seller: 1
# ADJ Property owner: 1
# Does not repersent market value for lake.: 1
# ADJ. Prop owner: 1
# INCLUDES PEROSNAL PROPERTY: 1
# INCLUDES PERSONAL PROEPRTY: 1
# Per listing "Turn Key all kitchen and bar equipment, tables, chairs, dishes remain.": 1
# PRIVAE SALE: 1
# PRIVTE: 1
# SOLD TIMES 1 YEAR: 1
# SOLD X IN ONE YEAR: 1
# Deleted: 1
# Unique property only individual dock slip on Trail Creek: 1
# significant pp value not disclosed: 1
# PURCHASED FOR DIRECT RAIL LINE ACCESS TO MANUFACTURING FACILITY IN SYRACUSE: 1
# Sold for purchase amount: 1
# Purchased to re-sell: 1
# Handyman special: 1
# not buildable: 1
# Sale price includes work still to be completed tls: 1
# building on ground is actually a negative value: 1
# Property needs lots of work: 1
# Furniture included in sale: 1
# kitchen, bath, windows, and hardwood floors right before sold: 1
# Purchased for recreational use (not used as home): 1
# INVALID- 599 CODE: 1
# Invalid - Sale of HWY land: 1
# BUYER LIVING IN HOME: 1
# INVESMENT PROPERTY: 1
# Buyer has 95% interest: 1
# Sellers will remain living there: 1
# Sold from the county: 1
# Sold from secretary of affiars: 1
# RESTRICTIONS: 1
# SALE INCLUDED EQUIPMENT: 1
# COMPLETION OF UNRECORDED OPTION TO PURCHASE: 1
# WILL BE BUILDING A DENTAL OFFICE: 1
# OUT OF TOWN BUYER: 1
# SELLER STATED SHE BOUGHT CHEAP BUT IT BECAME TOO MUCH FOR HER SO SHE SOLD IT QUICKLY TO GET RID OF IT.: 1
# Sale half of assessment - not used: 1
# SELLER LIVES OUT OF STATE: 1
# OUT OF STATE SELLER: 1
# privae sale: 1
# PROPERTY WAS A QUICK SALE & NEEDS LOTS OF REPAIR PER SELLER: 1
# INCLUDED 002-123011-00 & 002-103099-00; SELLERS WANTED OUT FROM UNDER THE PROPERTY: 1
# Sale under value for Nbhd: 1
# PROJECT HOUSE; PER PHONE CALL W/ SELLER: HOME WAS COMPLETELY GUTTED & NEEDS COMPLETED: 1
# SALE BETWEEN FATHER & SON: 1
# Quick claim deed: 1
# WRONG SALE PRICE FOR PARCEL: 1
# PART OF THE LAND IS TILLABLE - NOT MARKET VALUE: 1
# Cannot Confirm Sale Price, Area Land Values Alone Are Significantly Higher: 1
# significant land cleanup needed: 1
# home was a recent crime scene: 1
# FATHER TO SON: 1
# RELOCATION - PURCHASED: 1
# Bad Conition: 1

# %%
import re
from Levenshtein import distance as levenshtein_distance

def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = text.strip()
    return text

def dynamic_threshold(text_length):
    if text_length <= 10:
        return 3
    elif text_length <= 20:
        return 6
    else:
        return 12

def cluster_reasons_dynamic_threshold(reasons):
    reasons = [normalize_text(reason) for reason in reasons]
    groups = []
    visited = set()
    for reason in reasons:
        if reason in visited:
            continue
        reason_length = len(reason)
        threshold = dynamic_threshold(reason_length)
        current_group = [reason]
        visited.add(reason)
        for other_reason in reasons:
            if other_reason not in visited:
                other_length = len(other_reason)
                pair_threshold = min(threshold, dynamic_threshold(other_length))
                if levenshtein_distance(reason, other_reason) <= pair_threshold:
                    current_group.append(other_reason)
                    visited.add(other_reason)
        groups.append(current_group)
    return groups

def print_clusters_with_multiple_items(clusters):
    clusters_with_multiple_items = [cluster for cluster in clusters if len(cluster) > 1]
    print(f"Number of clusters with multiple reasons: {len(clusters_with_multiple_items)}")
    for i, cluster in enumerate(clusters_with_multiple_items):
        print(f"Cluster {i + 1}:")
        for reason in cluster:
            print(f"  - {reason}")
        print()

# %%
df_2023 = pd.read_csv("tippecanoe/Combined_Reconciliation_2023_2.csv")

df_2023_false = df_2023[df_2023['Reclassified'] == False]
reasons_2023 = df_2023_false['Explanation'].dropna().unique()
clusters_2023 = cluster_reasons_dynamic_threshold(reasons_2023)

print("Clusters of Similar Reasons:")
for i, cluster in enumerate(clusters_2023):
    print(f"Cluster {i + 1}: {cluster}")
# Out:
# Clusters of Similar Reasons:
# Cluster 1: ['adj property owner']
# Cluster 2: ['valued per ic 611442']
# Cluster 3: ['value per grm per ic 611439b']
# Cluster 4: ['interior not all complete at time of sale']
# Cluster 5: ['mutiproperty sale']
# Cluster 6: ['price recuction']
# Cluster 7: ['last lot in subdivision']
# Cluster 8: ['one of the last remaining lots selling for premium']
# Cluster 9: ['invalid  mostly land sale', 'invalid  portfoloio sale']
# Cluster 10: ['invalid  future valid sale same year']
# Cluster 11: ['invalid  large amount of land']
# Cluster 12: ['home vp sold for land']
# Cluster 13: ['invalid  excess res']
# Cluster 14: ['structures not habitable']
# Cluster 15: ['delevoper sale']
# Cluster 16: ['temporary transfer']
# Cluster 17: ['new owner is building a home']
# Cluster 18: ['invalid unresolved problems with deedwork']
# Cluster 19: ['foundation issues present at time of sale']
# Cluster 20: ['invalid  non market sale per dan', 'invalid  nonmarket transaction']
# Cluster 21: ['invalid  valid land']
# Cluster 22: ['home listing and sale includes a relocation clause']
# Cluster 23: ['sale is for outbuildings']
# Cluster 24: ['invalid  letter of condemation', 'invalid saleno consideration', 'invalid  no consideration']
# Cluster 25: ['the sdfid  is wrong  sale was used under sdfid c0720220001111']
# Cluster 26: ['downtown building needing lots of work']
# Cluster 27: ['changed values data entered after pull']
# Cluster 28: ['lauren changed in system after import']
# Cluster 29: ['sold to tenant', 'sold to gvt entity']
# Cluster 30: ['sales disclosure form unavailable']
# Cluster 31: ['old gas station  already applied obsolescence']
# Cluster 32: ['corrected sale id per lauren']
# Cluster 33: ['state sale to individual  no road access']
# Cluster 34: ['sale not submitted from auditors office in time to be validated before 2024', 'sale not submitted from auditors office in time to be validated before 2025']
# Cluster 35: ['gift or no consideration']
# Cluster 36: ['sold in 2019 for 160000 with no changes']
# Cluster 37: ['seller  buyer are same individual']
# Cluster 38: ['land and lake carry value  cannot adjust enough']
# Cluster 39: ['exchange of parcels']
# Cluster 40: ['put house in fair cond', 'put house in vp cond']
# Cluster 41: ['adjusted land influence', 'adjusted land influence factor']
# Cluster 42: ['new building since sale', 'sold building to tenant']
# Cluster 43: ['sold twince in one year', 'sold two times  one year', 'sold two times in one year', 'sold 3 time in one year']
# Cluster 44: ['seller lives out of state  needed to dispose of property']
# Cluster 45: ['property to be used for hunting only not residence']
# Cluster 46: ['major changes were made on reassessment']
# Cluster 47: ['includes doughnut shop property']
# Cluster 48: ['deed states land cannot be built upon per us air force']
# Cluster 49: ['too low for retail in that area']
# Cluster 50: ['purchased land wbillboard', 'purchased from landlord']
# Cluster 51: ['it only mh park sale']
# Cluster 52: ['sold wcomm']
# Cluster 53: ['includes equipment for car wash']
# Cluster 54: ['changed efp to ofp']
# Cluster 55: ['sale price does not represnet property value may have been dissolution of partnership no contact']
# Cluster 56: ['two properties purchased for one price  no designated price on individuals']
# Cluster 57: ['property sold to realtor from widow disposing of properties']
# Cluster 58: ['put house in fair cond buyer is sellers son seller said house needs a lot of repairs']
# Cluster 59: ['il  io  seller needed to dispose of property asap to move outof state']
# Cluster 60: ['spouse passed away  widow needed to sell']
# Cluster 61: ['duplciate sale', 'privale sale', 'coporate sale']
# Cluster 62: ['leasback sale']
# Cluster 63: ['originally marked invalid hotel']
# Cluster 64: ['parcel number is no longer an active number']
# Cluster 65: ['raltionship', 'realtionship', 'gardianship']
# Cluster 66: ['signficant change', 'signficant changes', 'signifiant changes', 'signifcant changes', 'sigificant changes', 'siginificant changes', 'signficiant changes', 'signiicant changes', 'signifigant changes', 'significate changes']
# Cluster 67: ['75 obs rem']
# Cluster 68: ['intangables included not assessable']
# Cluster 69: ['0 days on the market', '2 days on market', 'only 3 days on the market', 'two days on the market', 'days on market']
# Cluster 70: ['higher end home', 'upper end home']
# Cluster 71: ['no marketing time']
# Cluster 72: ['only 3 days on market', 'only 2 days on market', 'not full day on market', 'only two days on the market', 'i  not lised on market']
# Cluster 73: ['no money']
# Cluster 74: ['sales price', 'landlow price', 'low sae price']
# Cluster 75: ['no house', 'nonhouse']
# Cluster 76: ['has restricting for sale']
# Cluster 77: ['bought to tear down']
# Cluster 78: ['buyer and seller are the same']
# Cluster 79: ['no home on this parcel just buildings']
# Cluster 80: ['invalidsold to tenant', 'invalid pended at list', 'invalid pending at list', 'invalid pending at print']
# Cluster 81: ['invalidhandyman special good bones']
# Cluster 82: ['invalidlandlocked nonbuildable lots']
# Cluster 83: ['consideration includes purchase of easement']
# Cluster 84: ['building a house', 'building spec home']
# Cluster 85: ['spilt parcel']
# Cluster 86: ['habitat for humanity home', 'habitat for humanity sale', 'new habitat for humanity house']
# Cluster 87: ['invalid signifaicant changes']
# Cluster 88: ['invalid sale  sold twicie in one year']
# Cluster 89: ['invalid sale  significant amount of purchase property  purchased by dollar general']
# Cluster 90: ['invalid sale  sale included franchise of kfc']
# Cluster 91: ['invalid sale  sale amount lee than minimum in need of many repairs']
# Cluster 92: ['invalid sale  1880 log home  could not reach that price if new']
# Cluster 93: ['excluded  unknown sale', 'excluded  under 10000', 'excluded  has since sold', 'excluded  sold for 15k', 'excluded  sold for 4351', 'excluded  grade is a d1', 'excluded  invesstment', 'excluded  guardians deed']
# Cluster 94: ['excluded  has since sold in 2023', 'excluded  has since soldbad sale']
# Cluster 95: ['excluded  home owners own part of the lake however lake is not assessable']
# Cluster 96: ['excluded  d1 grade']
# Cluster 97: ['excluded  6 parcles in 1 sale price', 'excluded  5 parcels in sale price']
# Cluster 98: ['excluded  2 disclosures 14 interest']
# Cluster 99: ['excluded  2 disclosures and 1 deed on this parcel state fee was collected on 1st disclosure  this is 33rd interest']
# Cluster 100: ['excluded  sold for 10000', 'excluded  sold for 15000', 'excluded  sold for 10  under', 'excluded  sold for 14000', 'excluded  sold from church']
# Cluster 101: ['excluded  seller never lived in home']
# Cluster 102: ['excluded  correction of recording error']
# Cluster 103: ['excluded  buyerseller out of statecould not verify sale']
# Cluster 104: ['excluded  sale price includes 10 parcels', 'excluded  sale price includes 3 parcels']
# Cluster 105: ['excluded  purchased for inventory', 'excluded  purchased by county']
# Cluster 106: ['excluded  3 parcels included in sale']
# Cluster 107: ['excluded  sale on 3 separate disclosures']
# Cluster 108: ['excluded  sold and bought by to out of state company']
# Cluster 109: ['excluded  sold four times in one year']
# Cluster 110: ['excluded  includes personal items']
# Cluster 111: ['excluded  junk land']
# Cluster 112: ['excluded  cell tower on property']
# Cluster 113: ['excluded  no access']
# Cluster 114: ['excluded  new contruction after purchase']
# Cluster 115: ['excluded   clerical error on sales disclosure']
# Cluster 116: ['included  sale price was entered incorrectly on disclosure 3150']
# Cluster 117: ['excluded  no accesstresspassing']
# Cluster 118: ['personal use']
# Cluster 119: ['relocation service']
# Cluster 120: ['secondary home', 'second home']
# Cluster 121: ['no heatelectric']
# Cluster 122: ['sale between father and daughter']
# Cluster 123: ['buyers daughter will be living there seller moved out of state and wanted to get rid of']
# Cluster 124: ['sale included equipment']
# Cluster 125: ['sale half of assessment  not used']
# Cluster 126: ['seller stated she bought cheap but it became too much for her so she sold it quickly to get rid of it']
# Cluster 127: ['out of state seller']
# Cluster 128: ['out of town buyer']
# Cluster 129: ['relo company']
# Cluster 130: ['changed afte sale']
# Cluster 131: ['included pp', 'sale included pp', 'included a boat']
# Cluster 132: ['nc', 'vv', 'land', 'lsp', 'c']
# Cluster 133: ['inactivated parcel']
# Cluster 134: ['this one should have been charged a sales disclosure fee new person in assessors office marked wrong box']
# Cluster 135: ['buyers said that home needs some repairs']
# Cluster 136: ['home in need of extensive repair due to rupture of a water pipe and flooded interior']
# Cluster 137: ['seller purchased property for 10000 in march of 2021']
# Cluster 138: ['sales has 3 sales disclosures', 'sale included 3 sales disclosures', 'two sales disclosures']
# Cluster 139: ['husband died and she isnt able to take care of 2 homes']
# Cluster 140: ['seller had purchased in 2020 for exact same amt that he sold it for']
# Cluster 141: ['parcel was gifted to seller']
# Cluster 142: ['sale includes 01010305401  01010308401 res 7 com sold together']
# Cluster 143: ['sale amount leaa than min nbhd range 65k250k']
# Cluster 144: ['includes 01013301800 01013301900  01012500000 no inventory included  sale amount way over value for kit building']
# Cluster 145: ['sale amount included prospects of changing building']
# Cluster 146: ['building in p cond sale for land']
# Cluster 147: ['599 sale with vp cond not indicitive of nbhd']
# Cluster 148: ['property was a quick sale  needs lots of repair per seller']
# Cluster 149: ['sale under value for nbhd']
# Cluster 150: ['project house per phone call w seller home was completely gutted  needs completed']
# Cluster 151: ['correct mktmodel']
# Cluster 152: ['insufficant sales', 'insufficiant sales']
# Cluster 153: ['see the ratio']
# Cluster 154: ['value set by legislation']
# Cluster 155: ['50 intrest']
# Cluster 156: ['accessory parcel']
# Cluster 157: ['swmh  nada price']
# Cluster 158: ['significant person propertyinventory in sale']
# Cluster 159: ['sale crosses twsp lines']
# Cluster 160: ['sold to grandson']
# Cluster 161: ['created parcel per deed  map']
# Cluster 162: ['sale included a ppmh', 'sale includes camper']
# Cluster 163: ['valid 2021']
# Cluster 164: ['sold in 2021', 'just sold in 2023']
# Cluster 165: ['sold for highway purposes']
# Cluster 166: ['parcel deaded', 'parcel 1 of 2', 'parcel 1 of 3', 'parcel 1 of 5']
# Cluster 167: ['parcel not in proval']
# Cluster 168: ['in rati study as c2920220005354']
# Cluster 169: ['auditor rejected documentwrong legal', 'auditor rejected deedlegal']
# Cluster 170: ['parcel  not active']
# Cluster 171: ['sale well over nghb median']
# Cluster 172: ['no validation codes']
# Cluster 173: ['easements or rightofway grants']
# Cluster 174: ['maybe']
# Cluster 175: ['incoming producing property']
# Cluster 176: ['2 non contigious parcels sold']
# Cluster 177: ['331214340185000016', '331214220173000016']
# Cluster 178: ['2nd sale in 3 months']
# Cluster 179: ['331626310348000029 is primary', '331524000207000029 is primary']
# Cluster 180: ['330719430113000017']
# Cluster 181: ['330327000202000021']
# Cluster 182: ['331717431428000026']
# Cluster 183: ['92222 corrected sale price to 27000 from 169900  title company error']
# Cluster 184: ['all buildings very poor cond']
# Cluster 185: ['very poor cond']
# Cluster 186: ['oneparty sale']
# Cluster 187: ['invetment property']
# Cluster 188: ['includes parcel 301017', 'includes travel trailer']
# Cluster 189: ['land still ran as woods  no home yet']
# Cluster 190: ['one sale price for 4 non0contig properties']
# Cluster 191: ['sale price includes noncontig parcel 341006331019000002']
# Cluster 192: ['much work needed']
# Cluster 193: ['i4  sold to city of kokomo']
# Cluster 194: ['io  properties will be used residentialy in the future']
# Cluster 195: ['one party sold and closed']
# Cluster 196: ['per note incama incorrectly pricing exhorbitant sqft']
# Cluster 197: ['building razed afer sale']
# Cluster 198: ['sale price is for two non contig parcels', 'sale price is for two noncontig parcels']
# Cluster 199: ['previous owner buying back property']
# Cluster 200: ['one sale price for six parcels']
# Cluster 201: ['io  price includes purchase of franchise rights']
# Cluster 202: ['mfg home skewed sales']
# Cluster 203: ['ie  purchased to be used as residential']
# Cluster 204: ['sale of subsidized units  law prevails over sale']
# Cluster 205: ['purchase to fip']
# Cluster 206: ['land in state program']
# Cluster 207: ['very large home on over 5 acres this price does not match the market']
# Cluster 208: ['odd shaped parcel not the norm']
# Cluster 209: ['cannot confirm sale price area land values alone are significantly higher']
# Cluster 210: ['vancantland']
# Cluster 211: ['landonly']
# Cluster 212: ['sheriiffsale', 'sherriff sale', 'sherifs sale']
# Cluster 213: ['relocationpurchased']
# Cluster 214: ['7giftornoconsideration7giftornoconsideration']
# Cluster 215: ['oorecording issue']
# Cluster 216: ['same seller and buyer gorup mary louise miller']
# Cluster 217: ['environmental issues with land restricting availability']
# Cluster 218: ['sale included parcels in marshall county']
# Cluster 219: ['sold 16 days later for same amount']
# Cluster 220: ['sold w 74963  two disclosures total sale price 33000']
# Cluster 221: ['purchased by lakefront property owner']
# Cluster 222: ['yogi lot']
# Cluster 223: ['there is no way to justify this sale price']
# Cluster 224: ['sale of undivided 12 interest']
# Cluster 225: ['the lady that works for ks  f told me that the house has been gutted for years but no one has called to notify us about this']
# Cluster 226: ['new buyer overpaid just to get them out of the nbhd  hoarders and yelled at their own children alot  had 5 cats and 1 dog in house  needs gutted to studs  new owner has bleached the cement floors and still cant get the smell out']
# Cluster 227: ['sold 1 month later for 340000', 'sold 8 days later for 20000', 'sold 4 mos later for 352000', 'sold a month later for same price']
# Cluster 228: ['michelle harmeyer is a sister of shari lambert deceased']
# Cluster 229: ['transfer to relo company  then relo transfers to new owner']
# Cluster 230: ['dad selling to son']
# Cluster 231: ['ammf is taking title to property and will then transfer to new owner  not a sale']
# Cluster 232: ['sale back to original owner for same price']
# Cluster 233: ['swapped houses with neighbor']
# Cluster 234: ['mennonite mutual is taking title to property and will then transfer to new owner  not a sale']
# Cluster 235: ['buyer is ex wife to seller']
# Cluster 236: ['buyer and seller have same po box  see prc  disclosure']
# Cluster 237: ['property will not transfer until 2023']
# Cluster 238: ['sale price includes a nonassessable park model mh']
# Cluster 239: ['settlement of a disputed claim']
# Cluster 240: ['no mls', 'no av']
# Cluster 241: ['bought and sold soon after']
# Cluster 242: ['sold next day']
# Cluster 243: ['mls 480027 sold date in mls 09252020']
# Cluster 244: ['not within market valuesent questionnaire']
# Cluster 245: ['sale price is significantly below what comparable sales suggest the value should be', 'sale price is significantly below what comparable sales suggest it should be']
# Cluster 246: ['copy filed in error per preparer 7221 nt']
# Cluster 247: ['heirs getting rid of property']
# Cluster 248: ['invinv']
# Cluster 249: ['buyer sold 13 days after purchase']
# Cluster 250: ['copy filed in error per preparer deanna griggs 7121 nt']
# Cluster 251: ['new in ground pool 2022']
# Cluster 252: ['res and ci sold together']
# Cluster 253: ['builidng being finished']
# Cluster 254: ['pp included in sale']
# Cluster 255: ['buyer used to own property with seller']
# Cluster 256: ['coowner signing over his interest to the buyer']
# Cluster 257: ['subsequent sale in 2021 sale id 163374']
# Cluster 258: ['not rep of nbhd', 'not rep of nghb']
# Cluster 259: ['not open m']
# Cluster 260: ['sale price not within range of nearby comparable sales']
# Cluster 261: ['remains of old home exist on parcel']
# Cluster 262: ['special deed seller retains interest']
# Cluster 263: ['invstr to invstr']
# Cluster 264: ['bought from church']
# Cluster 265: ['questionnaire sent 82021']
# Cluster 266: ['not an open mrkt sale']
# Cluster 267: ['called buyer2nd od 3 sales on this property so far this year']
# Cluster 268: ['call made to seller']
# Cluster 269: ['sale price well below what comparable sales suggest the value should be']
# Cluster 270: ['mls 496872']
# Cluster 271: ['seller just bought in march 2021']
# Cluster 272: ['not in line with comparable sales']
# Cluster 273: ['special circumstancessubsequent sale']
# Cluster 274: ['mls 500476', 'mls 500313']
# Cluster 275: ['buyer and seller are same signerbuyer plans to builda 249000 sq ft spec industiral building on this parcel']
# Cluster 276: ['per phone call with seller on 92821 the buyer is his daughtersale price was significantly below the appraisal value']
# Cluster 277: ['comparable']
# Cluster 278: ['not rep of nghbnot an open mrkt sale', 'not rep of nghb valuesnot an open mrkt sale']
# Cluster 279: ['changing to food service']
# Cluster 280: ['not a sale name chg']
# Cluster 281: ['per mls sold on 12121 for 367500 3 dom']
# Cluster 282: ['sold significantly under appraisal']
# Cluster 283: ['mls  495290  not rep of nnghbd values']
# Cluster 284: ['duplicte of sale 164672']
# Cluster 285: ['per phone call with seller on 121521 the sale price was lower than the appraisal value']
# Cluster 286: ['amended disclosure']
# Cluster 287: ['same buyerseller']
# Cluster 288: ['sellers are heirs getting rid of the property', 'seller is an heir getting rid of the property', 'sellers were heirs getting rid of the property']
# Cluster 289: ['could not confirm if pp was included']
# Cluster 290: ['va sale', '2 sale']
# Cluster 291: ['part of porfolio sale', 'part of corp sale']
# Cluster 292: ['previous sale was gift deed']
# Cluster 293: ['receivers deed']
# Cluster 294: ['defunct gas station']
# Cluster 295: ['relocation']
# Cluster 296: ['house unlivable']
# Cluster 297: ['sale should have been marked invalid']
# Cluster 298: ['sold to bp']
# Cluster 299: ['owner deseased', 'owner deceased']
# Cluster 300: ['not withing range of comparable sales in nbhd']
# Cluster 301: ['rerecording']
# Cluster 302: ['seller contacted buyer']
# Cluster 303: ['sale pending 21623 255000']
# Cluster 304: ['rerecorded from may sale']
# Cluster 305: ['not 100 complete for 2023']
# Cluster 306: ['buyerseller associated companies']
# Cluster 307: ['house torn down after purchase']
# Cluster 308: ['includes 3 way liquor license']
# Cluster 309: ['includes perswonal property', 'mohome included personsal property']
# Cluster 310: ['includes tenants']
# Cluster 311: ['sold 2 x one year', 'sold 3x one year']
# Cluster 312: ['sold two times  one year 2nd sale is 72122']
# Cluster 313: ['sold to tenants motorcycle club']
# Cluster 314: ['new laminate flooring throughout repainted new granite countertops new water heater new appliances']
# Cluster 315: ['buyer lives directly across street']
# Cluster 316: ['sold after house burned']
# Cluster 317: ['new jiffy lube building for 2223']
# Cluster 318: ['sold for 1000 7920 value lowered by ptaboa']
# Cluster 319: ['property sold for 203514 12320']
# Cluster 320: ['parcel inactvie for 2223']
# Cluster 321: ['sold 92520 for 3400000 includes franchise rights equipment inventory']
# Cluster 322: ['high sale for unusual design and location of home']
# Cluster 323: ['value changed with ptaboa final']
# Cluster 324: ['high sale sold for 11000 over listing']
# Cluster 325: ['major structural changes to foundation and crawl to repairprevent moisture issues']
# Cluster 326: ['buyer listed as 9 years old signed by aif']
# Cluster 327: ['well maintained but high sale price for 2001 double wide']
# Cluster 328: ['sold for 160000 higher than 2020 sale and 270000 higher than 2018 sale']
# Cluster 329: ['house razed for 2324', 'house razed for 2223']
# Cluster 330: ['new double wide for 2324']
# Cluster 331: ['turnkey sale included all body shop equipment and spray booths']
# Cluster 332: ['house burned  137r filed']
# Cluster 333: ['new roof and hardwood floors in 2021 extensive new landscaping']
# Cluster 334: ['not market sale 100000 house']
# Cluster 335: ['new flooring in all 3 bedrooms and both bathrooms  high sale for 1989 double wide']
# Cluster 336: ['house was listed for 125000 carpenter realtor sold for 25000 over listing']
# Cluster 337: ['cabin only  carrying changes from ptaboa final']
# Cluster 338: ['new roof new vinyl fence new driveway new bathroom flooring and all new wiring']
# Cluster 339: ['converting building from dance studio to union hall for united auto workers']
# Cluster 340: ['sold above listing buyer and premium for the site all 35 acres professionally landscaped with small lake']
# Cluster 341: ['new roof new flooring throught new tiling in kitchen and bathrooms']
# Cluster 342: ['4 separate transfers not market between 82922 and 31523']
# Cluster 343: ['new roof in 2021 new kitchen appliances and washerdryer included in sale']
# Cluster 344: ['low sale of double wide sellers were living in missouri and needed a quick sale']
# Cluster 345: ['high sale small berm home']
# Cluster 346: ['new roof repainted interior new carpeting throughout']
# Cluster 347: ['new siding roof windows drywall sinks and quartz countertops']
# Cluster 348: ['not realistic sale price  was listed with remax up to time of sale for 59900']
# Cluster 349: ['new roof in 2021 refinished hardwood floors repainted interior']
# Cluster 350: ['new metal roof new french doors new appliances new patio in back']
# Cluster 351: ['house undervalued on 2022 assessment raising for 2324']
# Cluster 352: ['high sale 1984 double wide manufactured home']
# Cluster 353: ['high sale for this area small 1961 home 3 nearby sales in neigh 65000 or less']
# Cluster 354: ['small ranch on slab high sale for this area']
# Cluster 355: ['no money amount', 'low sale amount']
# Cluster 356: ['unknowledgable purchaser']
# Cluster 357: ['corp sale', 'close sale']
# Cluster 358: ['exchange of properties']
# Cluster 359: ['spec home']
# Cluster 360: ['2009 lc payoff']
# Cluster 361: ['sold 112421 for 34000']
# Cluster 362: ['buyer lives across road']
# Cluster 363: ['individual sale yoder to yoder and raber']
# Cluster 364: ['buyer plans to raze house']
# Cluster 365: ['part of same sale above on separate disclosure']
# Cluster 366: ['sale price in error should probably be 100000  questionable price since it is the same as 102020 sale']
# Cluster 367: ['per listing newly painted new flooring newer roof']
# Cluster 368: ['out of area buyer  home was used as weekend cabin  paid premium for 10 acres with large stocked lake']
# Cluster 369: ['sale includes solar panels battery backup  electrical system']
# Cluster 370: ['has market value amenities not assessable']
# Cluster 371: ['no home on this parcel']
# Cluster 372: ['property will be a church  transferred to the church']
# Cluster 373: ['will be guest house']
# Cluster 374: ['purchased to resell']
# Cluster 375: ['amematies included that are not assessable']
# Cluster 376: ['problems house gutted shortly after purchase']
# Cluster 377: ['motivates seller needs work']
# Cluster 378: ['handyman special']
# Cluster 379: ['invalid  contains market value amenities that are not assessable']
# Cluster 380: ['invalid  has amenites that are not assessable']
# Cluster 381: ['invalid  amenities are included that are not assessable']
# Cluster 382: ['invalid  handyman special']
# Cluster 383: ['invalid  per reassessment visit on 7622 ks']
# Cluster 384: ['invalid  unusual mrkt variability nonmrkt transaction']
# Cluster 385: ['mupltiple sales in one year', 'mutlipe sales same year']
# Cluster 386: ['invalid  transfer to holding companynonmarket transaction']
# Cluster 387: ['invalid  non mrkt transaction  sold for 7100 37 less than av', 'invalid  non mrkt transaction  sold for 42350 31 less than av', 'invalid  nonmarket transaction  sold for 357300 36 less than av', 'invalid  nonmrkt transaction  sold for 15600 11 less than av']
# Cluster 388: ['invalid  unusual mrkt variability']
# Cluster 389: ['invalid  sale price not refelctive of mrkt']
# Cluster 390: ['invalid  nonmrkt transaction  unusual mrkt variability', 'invalid  nonmarket transaction  unusual mrkt variability']
# Cluster 391: ['iv habitat sale to owneroccupant']
# Cluster 392: ['i  sold 3x']
# Cluster 393: ['i  interior issues']
# Cluster 394: ['v  v']
# Cluster 395: ['valid']
# Cluster 396: ['i  not lised']
# Cluster 397: ['i  two parels']
# Cluster 398: ['i  sold twic e']
# Cluster 399: ['paid off assumed lein of 19000']
# Cluster 400: ['unlisted sale rjd']
# Cluster 401: ['why would you sell something for half of what it appraised for not a good sale rjd']
# Cluster 402: ['mls  21822794 there are three lots original price was 25000 states at least two building sites seller took a loss in 7 months in an up market rjd']
# Cluster 403: ['sale of unbuildable lot for lake access', 'sale of unbuildable lot in lake community']
# Cluster 404: ['sale of unbuildable lot', 'sale of unbuildable lake lot jmm']
# Cluster 405: ['use total of']
# Cluster 406: ['this included the putnam county parcel all for the same price rjd']
# Cluster 407: ['expired mls shows home is gutted']
# Cluster 408: ['fouond no mls or zillow type listing seller is out of state buyer is out of town rjd']
# Cluster 409: ['son to dad']
# Cluster 410: ['buyer sold this to seller then bought it back for less rjd']
# Cluster 411: ['grandfather to granddaughter per obit of georgella davis rjd']
# Cluster 412: ['no mls foundbought by realtor rjd']
# Cluster 413: ['there are no pics of inside of house this time either house is a disaster or the realtor underpriced this terribly rjd']
# Cluster 414: ['needs work']
# Cluster 415: ['mini warehouse sale state mandate to assess at cost instead of market']
# Cluster 416: ['no mls found']
# Cluster 417: ['father to son']
# Cluster 418: ['found no mls rjd']
# Cluster 419: ['blc 21738825 listing includes lots 4245 equaling 284 acrestotal 4 lotssale price for all 4 lots 65000550915440015000020550915440016000020550915440017000020550915440018000020']
# Cluster 420: ['blc 21738825total 4 lotssale price for all 4 lots 65000550915440015000020550915440016000020550915440017000020550915440018000020']
# Cluster 421: ['needs tlc']
# Cluster 422: ['mls was expired at time of sale house needs cosmetics at least rjd']
# Cluster 423: ['changed to id  je']
# Cluster 424: ['sale of 50 interest on this sales dislcosure  mls']
# Cluster 425: ['remaining 50 interest sold on this disclosure  mls']
# Cluster 426: ['sales price low  mls']
# Cluster 427: ['shares sales price with lot 14  sold together  mls']
# Cluster 428: ['purchased and razed building  avs']
# Cluster 429: ['land of 48 acres for hunting  no home']
# Cluster 430: ['sale was originally from 1212022 but second parcel was not included on first disclosure or sale  so this sale only includes second parcel with sales price for both parcels  mls']
# Cluster 431: ['trimmed  could not get this price if brand new']
# Cluster 432: ['land only  12 interest', 'land only  going to build', 'land only lays wet in areas']
# Cluster 433: ['land only  plan to build in the future']
# Cluster 434: ['land only  some type 5  ditch']
# Cluster 435: ['land only has ditch']
# Cluster 436: ['poor cond  tear down']
# Cluster 437: ['previous value set by appeal']
# Cluster 438: ['tear down']
# Cluster 439: ['tear down land sale']
# Cluster 440: ['tear down or remo']
# Cluster 441: ['value set by ptaboa']
# Cluster 442: ['was listed for 1516k']
# Cluster 443: ['sale includes liquor license inventory']
# Cluster 444: ['see c5920210008817 same sale']
# Cluster 445: ['very high sale 279sf out of area buyer']
# Cluster 446: ['extremely high sale price 48300 acre for 383 acres']
# Cluster 447: ['building new habitat for humanity home']
# Cluster 448: ['sold to surviving spouse']
# Cluster 449: ['building being razed']
# Cluster 450: ['high sale  263sf small weekend log cabin out of area buyers']
# Cluster 451: ['very high sale 196sf for 2007 double wide on 106 acres']
# Cluster 452: ['converted to airbnb']
# Cluster 453: ['includes liquor license inventory fixtures']
# Cluster 454: ['complete rennovation in 2021 new roof siding and windows']
# Cluster 455: ['historic preservation home  buyers and sellers both out of area']
# Cluster 456: ['resale of property that was sold to nursing home to cover bills']
# Cluster 457: ['very well maintained home but high sale for small ranch home']
# Cluster 458: ['sale includes all equipment laundry and dry cleaning']
# Cluster 459: ['transfer between lenders']
# Cluster 460: ['interior of building gutted shell only']
# Cluster 461: ['included nc not yet completed', 'includes nc not yet completed', 'sale includes nc not 100 complete', 'price included nc not yet completed']
# Cluster 462: ['res imp']
# Cluster 463: ['not offerd to public']
# Cluster 464: ['relo sale']
# Cluster 465: ['exist in sales file did not match up with sale in proval']
# Cluster 466: ['transfer to t municipality']
# Cluster 467: ['very low sale six 60 x 110 lots out of area seller']
# Cluster 468: ['not legitimate price 175000 1995 ranch style home']
# Cluster 469: ['sold to library building razed for 2223']
# Cluster 470: ['house razed']
# Cluster 471: ['converted to a house for 2223']
# Cluster 472: ['12 lot sale on 2 disclosures  see below', '12 lot sale on 2 disclosures  see above']
# Cluster 473: ['includes shop equipment fixtures inventory']
# Cluster 474: ['discrepancy in actual sale price price also stated as 104900 by realtor']
# Cluster 475: ['entire interior repainted new listing flooring replacement windows vinyl siding']
# Cluster 476: ['res parcel in comm nhbd']
# Cluster 477: ['building needs major repairs seller just wanted to get rid of it  feels 500 is all its worth']
# Cluster 478: ['lot is small not buildable']
# Cluster 479: ['foundation in basement was crumbling  needed a lot of work buyer paid to have the basement fixed so the seller could sell the house to the buyer']
# Cluster 480: ['land is land locked and not indictive of normal market value']
# Cluster 481: ['commissioner sale', 'commissioners sale']
# Cluster 482: ['included  our sale price on sales disclosure is 148000']
# Cluster 483: ['significnt changes  and  now owner occupied']
# Cluster 484: ['significantamountofpersonalproperty']
# Cluster 485: ['invalid per bb  planned delvelopment']
# Cluster 486: ['mutli parcel saale', 'muti parcel deal']
# Cluster 487: ['113 non adj parcel tr', '12 adj parcel tr', '12 non adj parcel tr', '13 non adj parcel tr', '15 non adj parcel tr', '15 non adj parcel tr 8k', '16 non adj pacel tr', '1113 non adj parcel tr', '1213 non adj parcel tr', '1313 non adj parcel tr', '213 non adj parcel tr', '22 adj parcel tr 216k', '22 adj parcel tr 225k', '22 adj parcel tr 255k', '22 non adj parcel tr', '23 adj parcel tr 1175k', '23 adj parcel tr 375k', '23 non adj parcel tr', '25 non adj parcel tr', '26 non adj parcel tr', '313 non adj parcel tr', '33 non adj parcel tr', '35 non adj parcel tr', '413 non adj parcel tr', '45 non adj parcel tr', '45 non adj parcel tr 8k', '46 non adj parcel tr', '513 non adj parcel tr', '55 non adj parcel tr', '56 non adj parcel tr', '613 non adj parcel tr', '66 non adj parcel tr', '713 non adj parcel tr', '813 non adj parcel tr', '913 non adj parcel tr', 'land 12 adj parcel tr 15', 'land 23 adj parcel tr', 'land 44 adj parcel tr 4k']
# Cluster 488: ['12 adj parcel tr 38483 36 non adj parcel tr', '22 adj parcel 22 non adj parcel tr', '22 adj parcel tr 12 non adj parcel tr']
# Cluster 489: ['12 adj parcel tr 7k land', '22 adj parcel tr lsp 26av']
# Cluster 490: ['17 adj parcel tr vl sale to city']
# Cluster 491: ['2 pacels sold 1821194388 2 low price 33of av']
# Cluster 492: ['22 adj parcel tr', '22 adj parcel tr 46k', '22 adj parcel tr 85k', '22 adj parcel tr 8k', '48 adj parcel tr 15k', '78 adj parcel tr']
# Cluster 493: ['3 parcels sold 35', '4 parcel sold']
# Cluster 494: ['6187 adj parcel tr 46m buyer is hotel owner']
# Cluster 495: ['buyer is adj property owner 01881535517']
# Cluster 496: ['buyer owns adj property']
# Cluster 497: ['buyerseller same']
# Cluster 498: ['buyerseller same 13 adj parcel tr']
# Cluster 499: ['closed slae']
# Cluster 500: ['days on market 219', 'days on market 283']
# Cluster 501: ['grantee sb nicholas  gaul  sarah hull']
# Cluster 502: ['invald pending at print', 'invalid pended at listing']
# Cluster 503: ['invalid  unfinished rooms']
# Cluster 504: ['invalid bought by acquisition company parcel 2 of 3']
# Cluster 505: ['invalid bought by power company']
# Cluster 506: ['invalid bought by power company for utilty purposes']
# Cluster 507: ['invalid parcel 2 of 2     15118261159 per auditor no fee']
# Cluster 508: ['invalid previously preplumbed bath is now finished']
# Cluster 509: ['invalid sold at time of listing', 'pended at time of listing']
# Cluster 510: ['invalid unique characteristics atrium']
# Cluster 511: ['invalid unknown use']
# Cluster 512: ['land 3 parcel tr 5k', 'land 34 parcel tr 5k']
# Cluster 513: ['land to bldr', 'land to build', 'lot to bldr']
# Cluster 514: ['low price  34 of av', 'low price  40 of av']
# Cluster 515: ['lsp 27av', 'lsp 51 v', 'lsp46av']
# Cluster 516: ['lsp 49']
# Cluster 517: ['np 2324']
# Cluster 518: ['parcel 1of2 total of5 parcels on2 separatesdfs 382 total sp']
# Cluster 519: ['problem deed', 'tusteee deed']
# Cluster 520: ['purchased by tenant']
# Cluster 521: ['seller np']
# Cluster 522: ['unrecorded lc']
# Cluster 523: ['valid parcel 2of3 total of 5 parcels on 2 separate sdfs 382']
# Cluster 524: ['valid sale parcel 3 of 4']
# Cluster 525: ['this is a valid sale we used but the sdfid in our system is c7520210009203']
# Cluster 526: ['1031 exchange']
# Cluster 527: ['corrected deed']
# Cluster 528: ['percent complete']
# Cluster 529: ['highly modivated seller']
# Cluster 530: ['sign inside of bldg']
# Cluster 531: ['valid sale comimp']
# Cluster 532: ['for sale sign in yard']
# Cluster 533: ['inventory included']
# Cluster 534: ['distress sale']
# Cluster 535: ['seller will be leasing back from buyer']
# Cluster 536: ['on market 4yrs']
# Cluster 537: ['deystroyed property']
# Cluster 538: ['poor condgutted']
# Cluster 539: ['sold twic']
# Cluster 540: ['included bussiness']
# Cluster 541: ['signficiant changes made to property during appeal']
# Cluster 542: ['property purchased to keep competition out']
# Cluster 543: ['mini warehouse  lowest of three approaches not sale']
# Cluster 544: ['property was in need of extensive repair']
# Cluster 545: ['sale included nonreal property value not disclosed']
# Cluster 546: ['buyer not knowledgeable']
# Cluster 547: ['seller not knowledgeable of the market']

# %%
print("Clusters of Similar Reasons with Multiple Items:")
print_clusters_with_multiple_items(clusters_2023)
# Out:
# Clusters of Similar Reasons with Multiple Items:
# Number of clusters with multiple reasons: 79
# Cluster 1:
#   - invalid  mostly land sale
#   - invalid  portfoloio sale
#
# Cluster 2:
#   - invalid  non market sale per dan
#   - invalid  nonmarket transaction
#
# Cluster 3:
#   - invalid  letter of condemation
#   - invalid saleno consideration
#   - invalid  no consideration
#
# Cluster 4:
#   - sold to tenant
#   - sold to gvt entity
#
# Cluster 5:
#   - sale not submitted from auditors office in time to be validated before 2024
#   - sale not submitted from auditors office in time to be validated before 2025
#
# Cluster 6:
#   - put house in fair cond
#   - put house in vp cond
#
# Cluster 7:
#   - adjusted land influence
#   - adjusted land influence factor
#
# Cluster 8:
#   - new building since sale
#   - sold building to tenant
#
# Cluster 9:
#   - sold twince in one year
#   - sold two times  one year
#   - sold two times in one year
#   - sold 3 time in one year
#
# Cluster 10:
#   - purchased land wbillboard
#   - purchased from landlord
#
# Cluster 11:
#   - duplciate sale
#   - privale sale
#   - coporate sale
#
# Cluster 12:
#   - raltionship
#   - realtionship
#   - gardianship
#
# Cluster 13:
#   - signficant change
#   - signficant changes
#   - signifiant changes
#   - signifcant changes
#   - sigificant changes
#   - siginificant changes
#   - signficiant changes
#   - signiicant changes
#   - signifigant changes
#   - significate changes
#
# Cluster 14:
#   - 0 days on the market
#   - 2 days on market
#   - only 3 days on the market
#   - two days on the market
#   - days on market
#
# Cluster 15:
#   - higher end home
#   - upper end home
#
# Cluster 16:
#   - only 3 days on market
#   - only 2 days on market
#   - not full day on market
#   - only two days on the market
#   - i  not lised on market
#
# Cluster 17:
#   - sales price
#   - landlow price
#   - low sae price
#
# Cluster 18:
#   - no house
#   - nonhouse
#
# Cluster 19:
#   - invalidsold to tenant
#   - invalid pended at list
#   - invalid pending at list
#   - invalid pending at print
#
# Cluster 20:
#   - building a house
#   - building spec home
#
# Cluster 21:
#   - habitat for humanity home
#   - habitat for humanity sale
#   - new habitat for humanity house
#
# Cluster 22:
#   - excluded  unknown sale
#   - excluded  under 10000
#   - excluded  has since sold
#   - excluded  sold for 15k
#   - excluded  sold for 4351
#   - excluded  grade is a d1
#   - excluded  invesstment
#   - excluded  guardians deed
#
# Cluster 23:
#   - excluded  has since sold in 2023
#   - excluded  has since soldbad sale
#
# Cluster 24:
#   - excluded  6 parcles in 1 sale price
#   - excluded  5 parcels in sale price
#
# Cluster 25:
#   - excluded  sold for 10000
#   - excluded  sold for 15000
#   - excluded  sold for 10  under
#   - excluded  sold for 14000
#   - excluded  sold from church
#
# Cluster 26:
#   - excluded  sale price includes 10 parcels
#   - excluded  sale price includes 3 parcels
#
# Cluster 27:
#   - excluded  purchased for inventory
#   - excluded  purchased by county
#
# Cluster 28:
#   - secondary home
#   - second home
#
# Cluster 29:
#   - included pp
#   - sale included pp
#   - included a boat
#
# Cluster 30:
#   - nc
#   - vv
#   - land
#   - lsp
#   - c
#
# Cluster 31:
#   - sales has 3 sales disclosures
#   - sale included 3 sales disclosures
#   - two sales disclosures
#
# Cluster 32:
#   - insufficant sales
#   - insufficiant sales
#
# Cluster 33:
#   - sale included a ppmh
#   - sale includes camper
#
# Cluster 34:
#   - sold in 2021
#   - just sold in 2023
#
# Cluster 35:
#   - parcel deaded
#   - parcel 1 of 2
#   - parcel 1 of 3
#   - parcel 1 of 5
#
# Cluster 36:
#   - auditor rejected documentwrong legal
#   - auditor rejected deedlegal
#
# Cluster 37:
#   - 331214340185000016
#   - 331214220173000016
#
# Cluster 38:
#   - 331626310348000029 is primary
#   - 331524000207000029 is primary
#
# Cluster 39:
#   - includes parcel 301017
#   - includes travel trailer
#
# Cluster 40:
#   - sale price is for two non contig parcels
#   - sale price is for two noncontig parcels
#
# Cluster 41:
#   - sheriiffsale
#   - sherriff sale
#   - sherifs sale
#
# Cluster 42:
#   - sold 1 month later for 340000
#   - sold 8 days later for 20000
#   - sold 4 mos later for 352000
#   - sold a month later for same price
#
# Cluster 43:
#   - no mls
#   - no av
#
# Cluster 44:
#   - sale price is significantly below what comparable sales suggest the value should be
#   - sale price is significantly below what comparable sales suggest it should be
#
# Cluster 45:
#   - not rep of nbhd
#   - not rep of nghb
#
# Cluster 46:
#   - mls 500476
#   - mls 500313
#
# Cluster 47:
#   - not rep of nghbnot an open mrkt sale
#   - not rep of nghb valuesnot an open mrkt sale
#
# Cluster 48:
#   - sellers are heirs getting rid of the property
#   - seller is an heir getting rid of the property
#   - sellers were heirs getting rid of the property
#
# Cluster 49:
#   - va sale
#   - 2 sale
#
# Cluster 50:
#   - part of porfolio sale
#   - part of corp sale
#
# Cluster 51:
#   - owner deseased
#   - owner deceased
#
# Cluster 52:
#   - includes perswonal property
#   - mohome included personsal property
#
# Cluster 53:
#   - sold 2 x one year
#   - sold 3x one year
#
# Cluster 54:
#   - house razed for 2324
#   - house razed for 2223
#
# Cluster 55:
#   - no money amount
#   - low sale amount
#
# Cluster 56:
#   - corp sale
#   - close sale
#
# Cluster 57:
#   - mupltiple sales in one year
#   - mutlipe sales same year
#
# Cluster 58:
#   - invalid  non mrkt transaction  sold for 7100 37 less than av
#   - invalid  non mrkt transaction  sold for 42350 31 less than av
#   - invalid  nonmarket transaction  sold for 357300 36 less than av
#   - invalid  nonmrkt transaction  sold for 15600 11 less than av
#
# Cluster 59:
#   - invalid  nonmrkt transaction  unusual mrkt variability
#   - invalid  nonmarket transaction  unusual mrkt variability
#
# Cluster 60:
#   - sale of unbuildable lot for lake access
#   - sale of unbuildable lot in lake community
#
# Cluster 61:
#   - sale of unbuildable lot
#   - sale of unbuildable lake lot jmm
#
# Cluster 62:
#   - land only  12 interest
#   - land only  going to build
#   - land only lays wet in areas
#
# Cluster 63:
#   - included nc not yet completed
#   - includes nc not yet completed
#   - sale includes nc not 100 complete
#   - price included nc not yet completed
#
# Cluster 64:
#   - 12 lot sale on 2 disclosures  see below
#   - 12 lot sale on 2 disclosures  see above
#
# Cluster 65:
#   - commissioner sale
#   - commissioners sale
#
# Cluster 66:
#   - mutli parcel saale
#   - muti parcel deal
#
# Cluster 67:
#   - 113 non adj parcel tr
#   - 12 adj parcel tr
#   - 12 non adj parcel tr
#   - 13 non adj parcel tr
#   - 15 non adj parcel tr
#   - 15 non adj parcel tr 8k
#   - 16 non adj pacel tr
#   - 1113 non adj parcel tr
#   - 1213 non adj parcel tr
#   - 1313 non adj parcel tr
#   - 213 non adj parcel tr
#   - 22 adj parcel tr 216k
#   - 22 adj parcel tr 225k
#   - 22 adj parcel tr 255k
#   - 22 non adj parcel tr
#   - 23 adj parcel tr 1175k
#   - 23 adj parcel tr 375k
#   - 23 non adj parcel tr
#   - 25 non adj parcel tr
#   - 26 non adj parcel tr
#   - 313 non adj parcel tr
#   - 33 non adj parcel tr
#   - 35 non adj parcel tr
#   - 413 non adj parcel tr
#   - 45 non adj parcel tr
#   - 45 non adj parcel tr 8k
#   - 46 non adj parcel tr
#   - 513 non adj parcel tr
#   - 55 non adj parcel tr
#   - 56 non adj parcel tr
#   - 613 non adj parcel tr
#   - 66 non adj parcel tr
#   - 713 non adj parcel tr
#   - 813 non adj parcel tr
#   - 913 non adj parcel tr
#   - land 12 adj parcel tr 15
#   - land 23 adj parcel tr
#   - land 44 adj parcel tr 4k
#
# Cluster 68:
#   - 12 adj parcel tr 38483 36 non adj parcel tr
#   - 22 adj parcel 22 non adj parcel tr
#   - 22 adj parcel tr 12 non adj parcel tr
#
# Cluster 69:
#   - 12 adj parcel tr 7k land
#   - 22 adj parcel tr lsp 26av
#
# Cluster 70:
#   - 22 adj parcel tr
#   - 22 adj parcel tr 46k
#   - 22 adj parcel tr 85k
#   - 22 adj parcel tr 8k
#   - 48 adj parcel tr 15k
#   - 78 adj parcel tr
#
# Cluster 71:
#   - 3 parcels sold 35
#   - 4 parcel sold
#
# Cluster 72:
#   - days on market 219
#   - days on market 283
#
# Cluster 73:
#   - invald pending at print
#   - invalid pended at listing
#
# Cluster 74:
#   - invalid sold at time of listing
#   - pended at time of listing
#
# Cluster 75:
#   - land 3 parcel tr 5k
#   - land 34 parcel tr 5k
#
# Cluster 76:
#   - land to bldr
#   - land to build
#   - lot to bldr
#
# Cluster 77:
#   - low price  34 of av
#   - low price  40 of av
#
# Cluster 78:
#   - lsp 27av
#   - lsp 51 v
#   - lsp46av
#
# Cluster 79:
#   - problem deed
#   - tusteee deed

# %%
df_2024 = pd.read_csv("tippecanoe/Combined_Reconciliation_2024_2.csv")

df_2024_false = df_2024[df_2024['Reclassified'] == False]
reasons_2024 = df_2024_false['Explanation'].dropna().unique()
clusters_2024 = cluster_reasons_dynamic_threshold(reasons_2024)

print("Clusters of Similar Reasons:")
for i, cluster in enumerate(clusters_2024):
    print(f"Cluster {i + 1}: {cluster}")
# Out:
# Clusters of Similar Reasons:
# Cluster 1: ['property is part of a mh park will use the lowest of 3 approaches to value']
# Cluster 2: ['sale price includes work still to be completed tls']
# Cluster 3: ['relocation sale', 'relocation services', 'dulicate sale']
# Cluster 4: ['destressed sale']
# Cluster 5: ['land order done this year']
# Cluster 6: ['137  filed']
# Cluster 7: ['house relisted for higher value']
# Cluster 8: ['quick sale']
# Cluster 9: ['house needs work']
# Cluster 10: ['price reduction']
# Cluster 11: ['temporary transfer']
# Cluster 12: ['specialty property']
# Cluster 13: ['invalid  boarded up']
# Cluster 14: ['invalidlandfuture bld', 'invalid  ptrivate sale']
# Cluster 15: ['value must be lowest of three ind cost is not accurate']
# Cluster 16: ['sold for the land', 'sold to tenant']
# Cluster 17: ['residential building lot']
# Cluster 18: ['originally marked invalid  non market sale']
# Cluster 19: ['sale did not include new mh moved in']
# Cluster 20: ['right of way grant']
# Cluster 21: ['land and lake carry value  cannot adjust enough']
# Cluster 22: ['seller  buyer are same individual']
# Cluster 23: ['put house in vp cond']
# Cluster 24: ['put house in fair cond buyer is sellers son seller said house needs a lot of repairs']
# Cluster 25: ['sale price does not put value on structures']
# Cluster 26: ['seller from out of state needed to liquidate', 'seller moved out of state needed to liquidate']
# Cluster 27: ['sold to holding company']
# Cluster 28: ['sale price does not represnet property value may have been dissolution of partnership no contact']
# Cluster 29: ['changed efp to ofp']
# Cluster 30: ['property sold to realtor from widow disposing of properties']
# Cluster 31: ['two properties purchased for one price  no designated price on individuals']
# Cluster 32: ['spouse passed away  widow needed to sell']
# Cluster 33: ['includes equipment for car wash']
# Cluster 34: ['purchased with pp']
# Cluster 35: ['purchased land wbillboard']
# Cluster 36: ['il  io       property under appeal at time of sale']
# Cluster 37: ['it only mh park sale']
# Cluster 38: ['il  io  seller needed to dispose of property asap to move outof state']
# Cluster 39: ['sold wcomm']
# Cluster 40: ['sold significantly high than asking prive']
# Cluster 41: ['no money']
# Cluster 42: ['buyer walked away never took possession']
# Cluster 43: ['no house on this parcel']
# Cluster 44: ['student built']
# Cluster 45: ['sold second day on market']
# Cluster 46: ['intangables included']
# Cluster 47: ['going concern value included', 'going concern included in sale']
# Cluster 48: ['tear down']
# Cluster 49: ['interior ammenities are super for this house']
# Cluster 50: ['invalid mutiple parcels']
# Cluster 51: ['invalid contact']
# Cluster 52: ['obsol recently applied due to repairs needed']
# Cluster 53: ['sig changes']
# Cluster 54: ['includes liquor license']
# Cluster 55: ['under 10000seller is great aunt to buyer']
# Cluster 56: ['holding company']
# Cluster 57: ['not arm length']
# Cluster 58: ['same buyer seller in two months']
# Cluster 59: ['parcel deleted']
# Cluster 60: ['sold from city']
# Cluster 61: ['cell tower']
# Cluster 62: ['wrong price recorded']
# Cluster 63: ['has since sold']
# Cluster 64: ['guardians deed', 'warranty deed']
# Cluster 65: ['junk land']
# Cluster 66: ['out of state sale', 'out of state seller']
# Cluster 67: ['seller has interest']
# Cluster 68: ['junk property']
# Cluster 69: ['deleted']
# Cluster 70: ['buyer has 95 interest']
# Cluster 71: ['sellers will remain living there', 'seller will remain in property']
# Cluster 72: ['sold from the county']
# Cluster 73: ['sold from secretary of affiars']
# Cluster 74: ['restrictions']
# Cluster 75: ['sale included equipment', 'sale involved 2 homes']
# Cluster 76: ['completion of unrecorded option to purchase']
# Cluster 77: ['will be building a dental office']
# Cluster 78: ['out of town buyer']
# Cluster 79: ['seller stated she bought cheap but it became too much for her so she sold it quickly to get rid of it']
# Cluster 80: ['sale half of assessment  not used']
# Cluster 81: ['seller lives out of state']
# Cluster 82: ['privae sale']
# Cluster 83: ['resurvey']
# Cluster 84: ['property was a quick sale  needs lots of repair per seller']
# Cluster 85: ['included 00212301100  00210309900 sellers wanted out from under the property']
# Cluster 86: ['sale under value for nbhd']
# Cluster 87: ['project house per phone call w seller home was completely gutted  needs completed']
# Cluster 88: ['sale between father  son']
# Cluster 89: ['quick claim deed']
# Cluster 90: ['value set by legislation']
# Cluster 91: ['insufficant sales for imp ind study']
# Cluster 92: ['insufficant imp comm sale for a study']
# Cluster 93: ['wrong sale price for parcel']
# Cluster 94: ['part of the land is tillable  not market value']
# Cluster 95: ['cannot confirm sale price area land values alone are significantly higher']
# Cluster 96: ['significant land cleanup needed']
# Cluster 97: ['home was a recent crime scene']
# Cluster 98: ['invalid saleno consideration', 'invalidnew contruction', 'gift or no consideration']
# Cluster 99: ['land only']
# Cluster 100: ['father to son']
# Cluster 101: ['relocation  purchased']
# Cluster 102: ['invesment property', 'lakefront property']
# Cluster 103: ['buyer living in home']
# Cluster 104: ['invalid  sale of hwy land', 'invalid sold at listing', 'invalid grade is wrong', 'invalid  sold before listed']
# Cluster 105: ['invalid 599 code']
# Cluster 106: ['adj property owner', 'adj prop owner']
# Cluster 107: ['new const in progress']
# Cluster 108: ['non market sale', 'not market value']
# Cluster 109: ['realationship between buyer and seller']
# Cluster 110: ['does not repersent market value for lake']
# Cluster 111: ['includes perosnal property', 'includes personal proeprty']
# Cluster 112: ['per listing turn key all kitchen and bar equipment tables chairs dishes remain']
# Cluster 113: ['privte']
# Cluster 114: ['sold times 1 year']
# Cluster 115: ['sold two times in one year']
# Cluster 116: ['sold x in one year']
# Cluster 117: ['unique property only individual dock slip on trail creek']
# Cluster 118: ['significant pp not disclosed on sdf']
# Cluster 119: ['significant pp value not disclosed']
# Cluster 120: ['purchased for direct rail line access to manufacturing facility in syracuse']
# Cluster 121: ['sold for purchase amount']
# Cluster 122: ['purchased to resell']
# Cluster 123: ['handyman special']
# Cluster 124: ['not buildable']
# Cluster 125: ['ammenities and nontangilbes not assessable']
# Cluster 126: ['building on ground is actually a negative value']
# Cluster 127: ['property needs lots of work', 'home needs lots of repairs']
# Cluster 128: ['furniture included in sale', 'no house included in sale', 'cell tower included in sale']
# Cluster 129: ['kitchen bath windows and hardwood floors right before sold']
# Cluster 130: ['purchased for recreational use not used as home']
# Cluster 131: ['per legislation lowest of three approaches used', 'per legislation lowest of three approaches to value used']
# Cluster 132: ['buying out coowner']
# Cluster 133: ['dumped junk lots']
# Cluster 134: ['no mls found']
# Cluster 135: ['sold to granddaughter per obituary of gayle ream']
# Cluster 136: ['habitat home sale']
# Cluster 137: ['no mls found unadvetised sale of new parcel']
# Cluster 138: ['bought of market by realtor']
# Cluster 139: ['sale was originally from 1212022 but second parcel was not included on first disclosure or sale  so this sale only includes second parcel with sales price for both parcels  mls']
# Cluster 140: ['adjusted land influence factor']
# Cluster 141: ['bought by utility']
# Cluster 142: ['low sale seller in texas buyer in south carolina']
# Cluster 143: ['very high sale  plain older ranch home 1288 sf sold for 214sf']
# Cluster 144: ['high sale for small 2bedroom 50 year old ranch']
# Cluster 145: ['not transferred error in legal']
# Cluster 146: ['easement']
# Cluster 147: ['secretary of veterans affairs']
# Cluster 148: ['house incomplete']
# Cluster 149: ['relocation']
# Cluster 150: ['land is land locked and not indictive of normal market value']
# Cluster 151: ['lowest of 3 value per legislation']
# Cluster 152: ['commissioner sale', 'commissioners sale']
# Cluster 153: ['599 pcconly det gar  shed']
# Cluster 154: ['cabin in need of a lot of repair']
# Cluster 155: ['all bldgs in vp cond']
# Cluster 156: ['3 sdfs due to all parcels no contiguos']
# Cluster 157: ['house in need of lots of work and repairs', 'needs lots of work and repairs']
# Cluster 158: ['not valid due to work that needs to be done  numerous repairs needed']
# Cluster 159: ['needs work and repair', 'needs lots of work  repairs']
# Cluster 160: ['tearing all structures down']
# Cluster 161: ['house in need of a lot of work seller didnt want it anymore']
# Cluster 162: ['lowest out of the thre approaches to value']
# Cluster 163: ['building home']
# Cluster 164: ['cost approach']
# Cluster 165: ['part of larger sale']
# Cluster 166: ['property being sold as needs work']
# Cluster 167: ['signficant changes']
# Cluster 168: ['liquor license included']
# Cluster 169: ['significantamountofpersonalproperty']
# Cluster 170: ['part of a non adj parcel tr']
# Cluster 171: ['invalid pended at list', 'invalidpending at listing', 'invalidpending at print', 'invalidsold at listing', 'invaalidpending at listing', 'invlaidpending at listing', 'invalid pended at print']
# Cluster 172: ['invalid unique characteristics fountain']
# Cluster 173: ['invalidseller offers 5000 towards closing']
# Cluster 174: ['invalidseller offered credit towards home']
# Cluster 175: ['invalid 010324 vv']
# Cluster 176: ['np 2425']
# Cluster 177: ['low sale amount', 'low sale pice']
# Cluster 178: ['rerecorded deed to mishawaka drywall']
# Cluster 179: ['purchased for future build']
# Cluster 180: ['invalidvaant land']
# Cluster 181: ['invalid buyers used to live in unit 7']
# Cluster 182: ['special wd']
# Cluster 183: ['i  sale from fannie mae']
# Cluster 184: ['invalidnever hi the market']
# Cluster 185: ['corrective deed', 'corrected deed']
# Cluster 186: ['not valid buyer owns 01860381217']
# Cluster 187: ['incorrect entry sale deleted']
# Cluster 188: ['quick sale relocation']
# Cluster 189: ['invalid_triplex']
# Cluster 190: ['invalid']
# Cluster 191: ['invalidconsessions paid']
# Cluster 192: ['not valid buyer purchased01010581415']
# Cluster 193: ['pay off land contact']
# Cluster 194: ['significan change was in wrong nbh']
# Cluster 195: ['sale price included the cost of constructing a new building in 2024']
# Cluster 196: ['sale includes 15 acres of tillable land']
# Cluster 197: ['mh sound valued using nada']
# Cluster 198: ['per legislation lowest of 3 approaches to value was used']
# Cluster 199: ['percent complete']
# Cluster 200: ['sale involved pp']
# Cluster 201: ['support land']
# Cluster 202: ['separate disclosures']
# Cluster 203: ['realtor']
# Cluster 204: ['2022 sale']
# Cluster 205: ['insufficant sales']
# Cluster 206: ['pp mohome']
# Cluster 207: ['moving to nursing home']
# Cluster 208: ['on market too long']
# Cluster 209: ['outliar']
# Cluster 210: ['easement only']
# Cluster 211: ['sold before listed', 'sold before listing']
# Cluster 212: ['non market  sold before listed']
# Cluster 213: ['invalid   basement   lower level  finished  needs reviewed']
# Cluster 214: ['invalid  land only']
# Cluster 215: ['invalid  privat sale']
# Cluster 216: ['non market']
# Cluster 217: ['owner deceased']
# Cluster 218: ['seller not knowledgeable of market']
# Cluster 219: ['rerecording of parcel that was missed on original deed']
# Cluster 220: ['value set per appeal']
# Cluster 221: ['599 sale']
# Cluster 222: ['major changes to property']
# Cluster 223: ['house not 100 complete']
# Cluster 224: ['house not picked up']
# Cluster 225: ['bad conition']

# %%
print("Clusters of Similar Reasons with Multiple Items:")
print_clusters_with_multiple_items(clusters_2024)
# Out:
# Clusters of Similar Reasons with Multiple Items:
# Number of clusters with multiple reasons: 25
# Cluster 1:
#   - relocation sale
#   - relocation services
#   - dulicate sale
#
# Cluster 2:
#   - invalidlandfuture bld
#   - invalid  ptrivate sale
#
# Cluster 3:
#   - sold for the land
#   - sold to tenant
#
# Cluster 4:
#   - seller from out of state needed to liquidate
#   - seller moved out of state needed to liquidate
#
# Cluster 5:
#   - going concern value included
#   - going concern included in sale
#
# Cluster 6:
#   - guardians deed
#   - warranty deed
#
# Cluster 7:
#   - out of state sale
#   - out of state seller
#
# Cluster 8:
#   - sellers will remain living there
#   - seller will remain in property
#
# Cluster 9:
#   - sale included equipment
#   - sale involved 2 homes
#
# Cluster 10:
#   - invalid saleno consideration
#   - invalidnew contruction
#   - gift or no consideration
#
# Cluster 11:
#   - invesment property
#   - lakefront property
#
# Cluster 12:
#   - invalid  sale of hwy land
#   - invalid sold at listing
#   - invalid grade is wrong
#   - invalid  sold before listed
#
# Cluster 13:
#   - adj property owner
#   - adj prop owner
#
# Cluster 14:
#   - non market sale
#   - not market value
#
# Cluster 15:
#   - includes perosnal property
#   - includes personal proeprty
#
# Cluster 16:
#   - property needs lots of work
#   - home needs lots of repairs
#
# Cluster 17:
#   - furniture included in sale
#   - no house included in sale
#   - cell tower included in sale
#
# Cluster 18:
#   - per legislation lowest of three approaches used
#   - per legislation lowest of three approaches to value used
#
# Cluster 19:
#   - commissioner sale
#   - commissioners sale
#
# Cluster 20:
#   - house in need of lots of work and repairs
#   - needs lots of work and repairs
#
# Cluster 21:
#   - needs work and repair
#   - needs lots of work  repairs
#
# Cluster 22:
#   - invalid pended at list
#   - invalidpending at listing
#   - invalidpending at print
#   - invalidsold at listing
#   - invaalidpending at listing
#   - invlaidpending at listing
#   - invalid pended at print
#
# Cluster 23:
#   - low sale amount
#   - low sale pice
#
# Cluster 24:
#   - corrective deed
#   - corrected deed
#
# Cluster 25:
#   - sold before listed
#   - sold before listing
